# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/aakarshan/Documents/Documents HD2/SimpliLearn/New Session/Assignements/Chapter 4/Practice/DataScienceWithPython/OSL_Datasets/Lesson_09_Pandas/9.06_Introduction_to_Pandas_Panel/HousePrices.csv')

# %%
df.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %%
df.iloc[0]
# Out:
# date              2014-05-02 00:00:00
# price                        313000.0
# bedrooms                          3.0
# bathrooms                         1.5
# sqft_living                      1340
# sqft_lot                         7912
# floors                            1.5
# waterfront                          0
# view                                0
# condition                           3
# sqft_above                       1340
# sqft_basement                       0
# yr_built                         1955
# yr_renovated                     2005
# street           18810 Densmore Ave N
# city                        Shoreline
# statezip                     WA 98133
# country                           USA
# Name: 0, dtype: object

# %%
df.loc[0]
# Out:
# date              2014-05-02 00:00:00
# price                        313000.0
# bedrooms                          3.0
# bathrooms                         1.5
# sqft_living                      1340
# sqft_lot                         7912
# floors                            1.5
# waterfront                          0
# view                                0
# condition                           3
# sqft_above                       1340
# sqft_basement                       0
# yr_built                         1955
# yr_renovated                     2005
# street           18810 Densmore Ave N
# city                        Shoreline
# statezip                     WA 98133
# country                           USA
# Name: 0, dtype: object

# %%
df.size
# Out:
# 82800

# %%
df.memory_usage()
# Out:
# Index              132
# date             36800
# price            36800
# bedrooms         36800
# bathrooms        36800
# sqft_living      36800
# sqft_lot         36800
# floors           36800
# waterfront       36800
# view             36800
# condition        36800
# sqft_above       36800
# sqft_basement    36800
# yr_built         36800
# yr_renovated     36800
# street           36800
# city             36800
# statezip         36800
# country          36800
# dtype: int64

# %%
df['bedrooms'] = df['bedrooms'].astype('int32')

# %%
df.memory_usage()
# Out:
# Index              132
# date             36800
# price            36800
# bedrooms         18400
# bathrooms        36800
# sqft_living      36800
# sqft_lot         36800
# floors           36800
# waterfront       36800
# view             36800
# condition        36800
# sqft_above       36800
# sqft_basement    36800
# yr_built         36800
# yr_renovated     36800
# street           36800
# city             36800
# statezip         36800
# country          36800
# dtype: int64

# %%
df.groupby(['city']).mean(numeric_only=True)
# Out:
#                             price  bedrooms  bathrooms  sqft_living  \
# city
# Algona               2.072880e+05  3.200000   1.900000  1608.600000
# Auburn               2.993404e+05  3.420455   2.092330  2019.579545
# Beaux Arts Village   7.450000e+05  3.000000   1.750000  1490.000000
# Bellevue             8.471807e+05  3.804196   2.453671  2694.527972
# Black Diamond        3.396056e+05  3.222222   1.750000  1863.333333
# Bothell              4.814419e+05  3.606061   2.431818  2319.393939
# Burien               3.489472e+05  3.337838   1.746622  1815.337838
# Carnation            5.087520e+05  3.090909   2.170455  2392.454545
# Clyde Hill           1.321945e+06  4.181818   2.613636  3620.909091
# Covington            2.962304e+05  3.325581   1.970930  1792.558140
# Des Moines           3.049925e+05  3.241379   1.862069  1812.620690
# Duvall               4.039941e+05  3.380952   2.267857  2161.547619
# Enumclaw             3.076146e+05  3.178571   1.758929  1922.500000
# ...

# %%
df.groupby(['city']).max(numeric_only=True)
# Out:
#                           price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# city
# Algona                 262000.0         4       3.00         2163     22000
# Auburn                 900000.0         7       5.25         4930    235063
# Beaux Arts Village     745000.0         3       1.75         1490      9800
# Bellevue              7062500.0         7       6.25        10040    112521
# Black Diamond          650000.0         4       2.75         3350     68824
# Bothell                749995.0         5       3.25         3550     23265
# Burien                1035000.0         6       4.50         4380    136915
# Carnation             1680000.0         4       4.25         5584    280962
# Clyde Hill            3800000.0         5       5.50         7050     42840
# Covington             2199900.0         5       3.00         3490     78408
# Des Moines             950000.0         5       3.25         3740     49709
# ...

# %%
df['date']=pd.to_datetime(df['date'])

# %%
df.groupby(['city']).mean(numeric_only=True)
# Out:
#                             price  bedrooms  bathrooms  sqft_living  \
# city
# Algona               2.072880e+05  3.200000   1.900000  1608.600000
# Auburn               2.993404e+05  3.420455   2.092330  2019.579545
# Beaux Arts Village   7.450000e+05  3.000000   1.750000  1490.000000
# Bellevue             8.471807e+05  3.804196   2.453671  2694.527972
# Black Diamond        3.396056e+05  3.222222   1.750000  1863.333333
# Bothell              4.814419e+05  3.606061   2.431818  2319.393939
# Burien               3.489472e+05  3.337838   1.746622  1815.337838
# Carnation            5.087520e+05  3.090909   2.170455  2392.454545
# Clyde Hill           1.321945e+06  4.181818   2.613636  3620.909091
# Covington            2.962304e+05  3.325581   1.970930  1792.558140
# Des Moines           3.049925e+05  3.241379   1.862069  1812.620690
# Duvall               4.039941e+05  3.380952   2.267857  2161.547619
# Enumclaw             3.076146e+05  3.178571   1.758929  1922.500000
# ...

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.set_index(['date'], inplace=True)

# %%
df.head()
# Out:
#                 price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# date
# 2014-05-02   313000.0         3       1.50         1340      7912     1.5
# 2014-05-02  2384000.0         5       2.50         3650      9050     2.0
# 2014-05-02   342000.0         3       2.00         1930     11947     1.0
# 2014-05-02   420000.0         3       2.25         2000      8030     1.0
# 2014-05-02   550000.0         4       2.50         1940     10500     1.0
#
#             waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# date
# 2014-05-02           0     0          3        1340              0      1955
# 2014-05-02           0     4          5        3370            280      1921
# 2014-05-02           0     0          4        1930              0      1966
# 2014-05-02           0     0          4        1000           1000      1963
# 2014-05-02           0     0          4        1140            800      1976
#
# ...

# %%
df.resample('7D').mean(numeric_only=True)
# Out:
#                     price  bedrooms  bathrooms  sqft_living      sqft_lot  \
# date
# 2014-05-02  537825.723593  3.405276   2.140887  2096.707434  17072.395683
# 2014-05-09  540494.078704  3.467626   2.170863  2183.350120  15969.129496
# 2014-05-16  503177.314835  3.336207   2.125539  2050.887931  15963.959052
# 2014-05-23  541481.000000  3.353383   2.107143  2105.150376  15311.749373
# 2014-05-30  541795.477375  3.364238   2.177152  2106.582781  13088.496689
# 2014-06-06  555203.456743  3.409692   2.153084  2151.022026  13420.107930
# 2014-06-13  565039.462662  3.466270   2.207341  2164.007937  14267.521825
# 2014-06-20  549246.205968  3.416283   2.153994  2142.708141  15602.843318
# 2014-06-27  625640.983564  3.380342   2.191239  2184.258547  12626.818376
# 2014-07-04  555523.662598  3.396783   2.173592  2214.485255  15407.887399
#
#               floors  waterfront      view  condition   sqft_above  \
# date
# 2014-05-02  1.496403    0.002398  0.182254   3.434053  1775.916067
# ...

# %%
df.resample('M').mean(numeric_only=True)
# Out:
# /var/folders/mg/1999j9pd19537hny5ssp2zyc0000gn/T/ipykernel_18261/1222272418.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   df.resample('M').mean(numeric_only=True)
#                     price  bedrooms  bathrooms  sqft_living      sqft_lot  \
# date
# 2014-05-31  533822.837768  3.389706   2.139847  2114.912896  15959.428167
# 2014-06-30  547968.179909  3.404773   2.164640  2133.363469  14262.325379
# 2014-07-31  614407.818959  3.418070   2.204824  2225.468606  13824.958652
#
#               floors  waterfront      view  condition   sqft_above  \
# date
# 2014-05-31  1.493495    0.005656  0.247738   3.436086  1797.126131
# 2014-06-30  1.513538    0.008720  0.241854   3.459844  1822.765489
# 2014-07-31  1.557427    0.006126  0.217458   3.467075  1923.883614
#
#             sqft_basement     yr_built  yr_renovated
# date
# 2014-05-31     317.786765  1970.586538    826.834842
# ...

# %%
df.resample('Y').mean(numeric_only=True)
# Out:
# /var/folders/mg/1999j9pd19537hny5ssp2zyc0000gn/T/ipykernel_18261/1118857811.py:1: FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
#   df.resample('Y').mean(numeric_only=True)
#                     price  bedrooms  bathrooms  sqft_living      sqft_lot  \
# date
# 2014-12-31  551962.988473   3.40087   2.160815  2139.346957  14852.516087
#
#               floors  waterfront      view  condition   sqft_above  \
# date
# 2014-12-31  1.512065    0.007174  0.240652   3.451739  1827.265435
#
#             sqft_basement     yr_built  yr_renovated
# date
# 2014-12-31     312.081522  1970.786304    808.608261

# %%
df.plot()
# Out:
# <Axes: xlabel='date'>

# %%
df['price'].plot()
# Out:
# <Axes: xlabel='date'>

# %%
df = pd.read_csv('/Users/aakarshan/Documents/Documents HD2/SimpliLearn/New Session/Assignements/Chapter 4/Practice/DataScienceWithPython/OSL_Datasets/Lesson_09_Pandas/9.06_Introduction_to_Pandas_Panel/HousePrices.csv').query('city=="Seatle"').to_csv('Seatle.csv')

# %%
df = pd.read_csv('Seatle.csv')

# %%
df.head()
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, date, price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, sqft_above, sqft_basement, yr_built, yr_renovated, street, city, statezip, country]
# Index: []

# %%
df = pd.read_csv('/Users/aakarshan/Documents/Documents HD2/SimpliLearn/New Session/Assignements/Chapter 4/Practice/DataScienceWithPython/OSL_Datasets/Lesson_09_Pandas/9.06_Introduction_to_Pandas_Panel/HousePrices.csv')

# %%
df.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %%
df.set_index(['date'], inplace=True)

# %%
df.head()
# Out:
#                          price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# date
# 2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#                      floors  waterfront  view  condition  sqft_above  \
# date
# 2014-05-02 00:00:00     1.5           0     0          3        1340
# 2014-05-02 00:00:00     2.0           0     4          5        3370
# 2014-05-02 00:00:00     1.0           0     0          4        1930
# 2014-05-02 00:00:00     1.0           0     0          4        1000
# 2014-05-02 00:00:00     1.0           0     0          4        1140
#
#                      sqft_basement  yr_built  yr_renovated  \
# date
# ...

# %%
df.reset_index()
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
df.reset_index(inplace=True)

# %%
df.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %%
df. set_index(['date','price'], inplace=True)

# %%
df.head()
# Out:
#                                bedrooms  bathrooms  sqft_living  sqft_lot  \
# date                price
# 2014-05-02 00:00:00 313000.0        3.0       1.50         1340      7912
#                     2384000.0       5.0       2.50         3650      9050
#                     342000.0        3.0       2.00         1930     11947
#                     420000.0        3.0       2.25         2000      8030
#                     550000.0        4.0       2.50         1940     10500
#
#                                floors  waterfront  view  condition  \
# date                price
# 2014-05-02 00:00:00 313000.0      1.5           0     0          3
#                     2384000.0     2.0           0     4          5
#                     342000.0      1.0           0     0          4
#                     420000.0      1.0           0     0          4
#                     550000.0      1.0           0     0          4
#
# ...

# %%
df.plot()
# Out:
# <Axes: xlabel='date,price'>

# %%
df.reset_index(inplace=True)

# %%
df = pd.read_csv('/Users/aakarshan/Documents/Documents HD2/SimpliLearn/New Session/Assignements/Chapter 4/Practice/DataScienceWithPython/OSL_Datasets/Lesson_09_Pandas/9.06_Introduction_to_Pandas_Panel/HousePrices.csv', index_col=['date'])

# %%
df.head()
# Out:
#                          price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# date
# 2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#                      floors  waterfront  view  condition  sqft_above  \
# date
# 2014-05-02 00:00:00     1.5           0     0          3        1340
# 2014-05-02 00:00:00     2.0           0     4          5        3370
# 2014-05-02 00:00:00     1.0           0     0          4        1930
# 2014-05-02 00:00:00     1.0           0     0          4        1000
# 2014-05-02 00:00:00     1.0           0     0          4        1140
#
#                      sqft_basement  yr_built  yr_renovated  \
# date
# ...

# %%
df.reset_index()
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
##Merging

# %%
df1 = pd.read_csv('/Users/aakarshan/Documents/Documents HD2/SimpliLearn/New Session/Assignements/Chapter 4/Practice/DataScienceWithPython/OSL_Datasets/Lesson 11_Data_Wrangling/11.04_Merging/Merge1.csv')
df2 = pd.read_csv('/Users/aakarshan/Documents/Documents HD2/SimpliLearn/New Session/Assignements/Chapter 4/Practice/DataScienceWithPython/OSL_Datasets/Lesson 11_Data_Wrangling/11.04_Merging/Merge2.csv')

# %%
df1
# Out:
#           date      a   b    c
# 0   2022-01-01   9000  35  140
# 1   2022-01-02   8000  12  920
# 2   2022-01-03  69000  42  370
# 3   2022-01-04  81000  29  900
# 4   2022-01-05  91000  35  770
# ..         ...    ...  ..  ...
# 85  2022-03-27  37000  90  260
# 86  2022-03-28  24000  24  950
# 87  2022-03-29  44000   7  400
# 88  2022-03-30  31000  10  600
# 89  2022-03-31  28000  65  740
#
# [90 rows x 4 columns]

# %%
df2
# Out:
#           date      a   b    c
# 0   2022-03-01  12000  50   60
# 1   2022-03-02  27000  90  990
# 2   2022-03-03  19000  17  750
# 3   2022-03-04  70000  60  900
# 4   2022-03-05   6000   7  810
# 5   2022-03-06  10000  98  730
# 6   2022-03-07  41000  21  710
# 7   2022-03-08  80000  76  200
# 8   2022-03-09  78000  46  200
# 9   2022-03-10  74000  67   50
# 10  2022-03-11  13000  20   70
# 11  2022-03-12   9000   8  100
# 12  2022-03-13  44000  56  350
# 13  2022-03-14  44000  34  370
# 14  2022-03-15  39000  29  420
# 15  2022-03-16  21000  37  920
# 16  2022-03-17  59000   1  480
# 17  2022-03-18  19000  17  850
# 18  2022-03-19  74000  34  730
# 19  2022-03-20   6000  89  100
# 20  2022-03-21  67000  37   70
# 21  2022-03-22  74000  12   70
# 22  2022-03-23  31000  43  340
# 23  2022-03-24  12000  13  850
# 24  2022-03-25  94000  81  930
# 25  2022-03-26  85000   7  650
# 26  2022-03-27  17000  89  230
# 27  2022-03-28  97000  69  790
# 28  2022-03-29  47000  54  970
# ...

# %%
pd.merge(df1,df2,on=['date'])
# Out:
#           date    a_x  b_x  c_x    a_y  b_y  c_y
# 0   2022-03-01  16000   29  360  12000   50   60
# 1   2022-03-02  56000   73  990  27000   90  990
# 2   2022-03-03   3000   99  650  19000   17  750
# 3   2022-03-04  36000   94  310  70000   60  900
# 4   2022-03-05  59000   17  600   6000    7  810
# 5   2022-03-06  35000   57  450  10000   98  730
# 6   2022-03-07  86000   98  130  41000   21  710
# 7   2022-03-08  69000   44   60  80000   76  200
# 8   2022-03-09  21000   64  930  78000   46  200
# 9   2022-03-10  45000   83  670  74000   67   50
# 10  2022-03-11  65000   83  910  13000   20   70
# 11  2022-03-12  86000   50  280   9000    8  100
# 12  2022-03-13  35000   57  790  44000   56  350
# 13  2022-03-14  14000    2   50  44000   34  370
# 14  2022-03-15  87000   72  350  39000   29  420
# 15  2022-03-16  55000   58  990  21000   37  920
# 16  2022-03-17   3000   27  160  59000    1  480
# 17  2022-03-18  58000   70   50  19000   17  850
# ...

# %%
pd.merge(df1,df2,on=['date'],how='outer')
# Out:
#           date    a_x  b_x  c_x      a_y   b_y    c_y
# 0   2022-01-01   9000   35  140      NaN   NaN    NaN
# 1   2022-01-02   8000   12  920      NaN   NaN    NaN
# 2   2022-01-03  69000   42  370      NaN   NaN    NaN
# 3   2022-01-04  81000   29  900      NaN   NaN    NaN
# 4   2022-01-05  91000   35  770      NaN   NaN    NaN
# ..         ...    ...  ...  ...      ...   ...    ...
# 85  2022-03-27  37000   90  260  17000.0  89.0  230.0
# 86  2022-03-28  24000   24  950  97000.0  69.0  790.0
# 87  2022-03-29  44000    7  400  47000.0  54.0  970.0
# 88  2022-03-30  31000   10  600  72000.0  27.0  600.0
# 89  2022-03-31  28000   65  740  80000.0  17.0  370.0
#
# [90 rows x 7 columns]

# %%
df1.rename(columns={'date':'Date'}, inplace=True)

# %%
df1.head()
# Out:
#          Date      a   b    c
# 0  2022-01-01   9000  35  140
# 1  2022-01-02   8000  12  920
# 2  2022-01-03  69000  42  370
# 3  2022-01-04  81000  29  900
# 4  2022-01-05  91000  35  770

# %%
pd.merge(df1,df2,left_on=['Date'],right_on=['date'],how='outer')
# Out:
#           Date    a_x  b_x  c_x        date      a_y   b_y    c_y
# 0   2022-01-01   9000   35  140         NaN      NaN   NaN    NaN
# 1   2022-01-02   8000   12  920         NaN      NaN   NaN    NaN
# 2   2022-01-03  69000   42  370         NaN      NaN   NaN    NaN
# 3   2022-01-04  81000   29  900         NaN      NaN   NaN    NaN
# 4   2022-01-05  91000   35  770         NaN      NaN   NaN    NaN
# ..         ...    ...  ...  ...         ...      ...   ...    ...
# 85  2022-03-27  37000   90  260  2022-03-27  17000.0  89.0  230.0
# 86  2022-03-28  24000   24  950  2022-03-28  97000.0  69.0  790.0
# 87  2022-03-29  44000    7  400  2022-03-29  47000.0  54.0  970.0
# 88  2022-03-30  31000   10  600  2022-03-30  72000.0  27.0  600.0
# 89  2022-03-31  28000   65  740  2022-03-31  80000.0  17.0  370.0
#
# [90 rows x 8 columns]

# %%
df1.set_index(['Date'], inplace=True)
df2.set_index(['date'], inplace=True)

# %%
#To merge, give left_index and right_index as True, else merge will faile due to wrong index names
pd.merge(df1,df2,left_index=True,right_index=True, how='outer')
# Out:
#               a_x  b_x  c_x      a_y   b_y    c_y
# 2022-01-01   9000   35  140      NaN   NaN    NaN
# 2022-01-02   8000   12  920      NaN   NaN    NaN
# 2022-01-03  69000   42  370      NaN   NaN    NaN
# 2022-01-04  81000   29  900      NaN   NaN    NaN
# 2022-01-05  91000   35  770      NaN   NaN    NaN
# ...           ...  ...  ...      ...   ...    ...
# 2022-03-27  37000   90  260  17000.0  89.0  230.0
# 2022-03-28  24000   24  950  97000.0  69.0  790.0
# 2022-03-29  44000    7  400  47000.0  54.0  970.0
# 2022-03-30  31000   10  600  72000.0  27.0  600.0
# 2022-03-31  28000   65  740  80000.0  17.0  370.0
#
# [90 rows x 6 columns]

# %%
pd.merge(df1,df2,left_index=True,right_index=True,how='outer',suffixes=('_BayeinSe','_DayeinSe'))
# Out:
#             a_BayeinSe  b_BayeinSe  c_BayeinSe  a_DayeinSe  b_DayeinSe  \
# 2022-01-01        9000          35         140         NaN         NaN
# 2022-01-02        8000          12         920         NaN         NaN
# 2022-01-03       69000          42         370         NaN         NaN
# 2022-01-04       81000          29         900         NaN         NaN
# 2022-01-05       91000          35         770         NaN         NaN
# ...                ...         ...         ...         ...         ...
# 2022-03-27       37000          90         260     17000.0        89.0
# 2022-03-28       24000          24         950     97000.0        69.0
# 2022-03-29       44000           7         400     47000.0        54.0
# 2022-03-30       31000          10         600     72000.0        27.0
# 2022-03-31       28000          65         740     80000.0        17.0
#
#             c_DayeinSe
# 2022-01-01         NaN
# 2022-01-02         NaN
# 2022-01-03         NaN
# ...

# %%
df.isna().sum()
# Out:
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# street           0
# city             0
# statezip         0
# country          0
# dtype: int64

# %%
df.dropna()
# Out:
#                             price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# date
# 2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340      7912
# 2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650      9050
# 2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930     11947
# 2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000      8030
# 2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940     10500
# ...                           ...       ...        ...          ...       ...
# 2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510      6360
# 2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460      7573
# 2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010      7014
# 2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090      6630
# 2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490      8102
#
# ...

# %%
df.dropna(axis=1)
# Out:
#                             price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# date
# 2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340      7912
# 2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650      9050
# 2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930     11947
# 2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000      8030
# 2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940     10500
# ...                           ...       ...        ...          ...       ...
# 2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510      6360
# 2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460      7573
# 2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010      7014
# 2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090      6630
# 2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490      8102
#
# ...

# %%
#Filling Null values

# %%
import numpy as np

# %%
data = {'a':[1,2,np.nan],'b':[5,np.nan,np.nan],'c':[1,2,3]}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#      a    b  c
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.fillna(value=3)
# Out:
#      a    b  c
# 0  1.0  5.0  1
# 1  2.0  3.0  2
# 2  3.0  3.0  3

# %%
df.fillna(method='ffill')
# Out:
# /var/folders/mg/1999j9pd19537hny5ssp2zyc0000gn/T/ipykernel_18261/1193302488.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill')
#      a    b  c
# 0  1.0  5.0  1
# 1  2.0  5.0  2
# 2  2.0  5.0  3

# %%
df.ffill()
# Out:
#      a    b  c
# 0  1.0  5.0  1
# 1  2.0  5.0  2
# 2  2.0  5.0  3

# %%
df.bfill()
# Out:
#      a    b  c
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.fillna(value=df['a'].mean())
# Out:
#      a    b  c
# 0  1.0  5.0  1
# 1  2.0  1.5  2
# 2  1.5  1.5  3

# %%
df.fillna(np.mean(df))
# Out:
#           a         b  c
# 0  1.000000  5.000000  1
# 1  2.000000  2.333333  2
# 2  2.333333  2.333333  3

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/Users/aakarshan/Documents/Documents HD2/SimpliLearn/New Session/Assignements/Chapter 4/Practice/DataScienceWithPython/OSL_Datasets/Lesson 11_Data_Wrangling/11.08_Data_Binning_Formatting_and_Normalization/CarPrices.csv')

# %%
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
df.set_index(['car_ID'],inplace=True)

# %%
df.isna().sum()
# Out:
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
df.dropna()
# Out:
#         symboling                   CarName fueltype aspiration doornumber  \
# car_ID
# 1               3        alfa-romero giulia      gas        std        two
# 2               3       alfa-romero stelvio      gas        std        two
# 3               1  alfa-romero Quadrifoglio      gas        std        two
# 4               2               audi 100 ls      gas        std       four
# 5               2                audi 100ls      gas        std       four
# ...           ...                       ...      ...        ...        ...
# 201            -1           volvo 145e (sw)      gas        std       four
# 202            -1               volvo 144ea      gas      turbo       four
# 203            -1               volvo 244dl      gas        std       four
# 204            -1                 volvo 246   diesel      turbo       four
# 205            -1               volvo 264gl      gas      turbo       four
#
# ...

# %%
df.head()
# Out:
#         symboling                   CarName fueltype aspiration doornumber  \
# car_ID
# 1               3        alfa-romero giulia      gas        std        two
# 2               3       alfa-romero stelvio      gas        std        two
# 3               1  alfa-romero Quadrifoglio      gas        std        two
# 4               2               audi 100 ls      gas        std       four
# 5               2                audi 100ls      gas        std       four
#
#             carbody drivewheel enginelocation  wheelbase  carlength  ...  \
# car_ID                                                               ...
# 1       convertible        rwd          front       88.6      168.8  ...
# 2       convertible        rwd          front       88.6      168.8  ...
# 3         hatchback        rwd          front       94.5      171.2  ...
# 4             sedan        fwd          front       99.8      176.6  ...
# ...

# %%
df.dtypes
# Out:
# symboling             int64
# CarName              object
# fueltype             object
# aspiration           object
# doornumber           object
# carbody              object
# drivewheel           object
# enginelocation       object
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight            int64
# enginetype           object
# cylindernumber       object
# enginesize            int64
# fuelsystem           object
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower            int64
# peakrpm               int64
# citympg               int64
# highwaympg            int64
# price               float64
# dtype: object

# %%
ColName = [x for x in df.columns if df[x].dtype == 'object']

# %%
ColName
# Out:
# ['CarName',
#  'fueltype',
#  'aspiration',
#  'doornumber',
#  'carbody',
#  'drivewheel',
#  'enginelocation',
#  'enginetype',
#  'cylindernumber',
#  'fuelsystem']

# %%
df[ColName] = df[ColName].astype('string')

# %%
df.dtypes
# Out:
# symboling                    int64
# CarName             string[python]
# fueltype            string[python]
# aspiration          string[python]
# doornumber          string[python]
# carbody             string[python]
# drivewheel          string[python]
# enginelocation      string[python]
# wheelbase                  float64
# carlength                  float64
# carwidth                   float64
# carheight                  float64
# curbweight                   int64
# enginetype          string[python]
# cylindernumber      string[python]
# enginesize                   int64
# fuelsystem          string[python]
# boreratio                  float64
# stroke                     float64
# compressionratio           float64
# horsepower                   int64
# peakrpm                      int64
# citympg                      int64
# highwaympg                   int64
# price                      float64
# dtype: object

# %%
df.columns
# Out:
# Index(['symboling', 'CarName', 'fueltype', 'aspiration', 'doornumber',
#        'carbody', 'drivewheel', 'enginelocation', 'wheelbase', 'carlength',
#        'carwidth', 'carheight', 'curbweight', 'enginetype', 'cylindernumber',
#        'enginesize', 'fuelsystem', 'boreratio', 'stroke', 'compressionratio',
#        'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price'],
#       dtype='object')

# %%
df['CarName']
# Out:
# car_ID
# 1            alfa-romero giulia
# 2           alfa-romero stelvio
# 3      alfa-romero Quadrifoglio
# 4                   audi 100 ls
# 5                    audi 100ls
#                  ...
# 201             volvo 145e (sw)
# 202                 volvo 144ea
# 203                 volvo 244dl
# 204                   volvo 246
# 205                 volvo 264gl
# Name: CarName, Length: 205, dtype: string

# %%
df['Car Name'] = df['CarName'].str.split(' ').str.get(0)

# %%
df['Car Name']
# Out:
# car_ID
# 1      alfa-romero
# 2      alfa-romero
# 3      alfa-romero
# 4             audi
# 5             audi
#           ...
# 201          volvo
# 202          volvo
# 203          volvo
# 204          volvo
# 205          volvo
# Name: Car Name, Length: 205, dtype: object

# %%
df['Car Name'].unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'maxda', 'mazda', 'buick', 'mercury',
#        'mitsubishi', 'Nissan', 'nissan', 'peugeot', 'plymouth', 'porsche',
#        'porcshce', 'renault', 'saab', 'subaru', 'toyota', 'toyouta',
#        'vokswagen', 'volkswagen', 'vw', 'volvo'], dtype=object)

# %%
cols = {'maxda':'mazda','Nissan':'nissan','porcshce':'porsche','toyouta':'toyota','vokswagen':'volkswagen','vw':'volkswagen'}

# %%
df['Car Name'] = df['Car Name'].replace(cols)

# %%
df['Car Name'].unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'mazda', 'buick', 'mercury', 'mitsubishi',
#        'nissan', 'peugeot', 'plymouth', 'porsche', 'renault', 'saab',
#        'subaru', 'toyota', 'volkswagen', 'volvo'], dtype=object)

# %%
##Standardisation Of Data

# %%
#Standardisation using Max

# %%
df['peakrpm'].head()
# Out:
# car_ID
# 1    5000
# 2    5000
# 3    5000
# 4    5500
# 5    5500
# Name: peakrpm, dtype: int64

# %%
df['SF_PeakRpm'] = df['peakrpm']/df['peakrpm'].max()

# %%
df['SF_PeakRpm'].head()
# Out:
# car_ID
# 1    0.757576
# 2    0.757576
# 3    0.757576
# 4    0.833333
# 5    0.833333
# Name: SF_PeakRpm, dtype: float64

# %%
##Standardisation using Min-Max

# %%
df['MM_PeakRpm'] = (df['peakrpm']-df['peakrpm'].min())/(df['peakrpm'].max()-df['peakrpm'].min())

# %%
df['MM_PeakRpm'].head()
# Out:
# car_ID
# 1    0.346939
# 2    0.346939
# 3    0.346939
# 4    0.551020
# 5    0.551020
# Name: MM_PeakRpm, dtype: float64

# %%
##Data Binning and Standardisation

# %%
df = pd.read_csv('/Users/aakarshan/Documents/Documents HD2/SimpliLearn/New Session/Assignements/Chapter 4/Practice/DataScienceWithPython/OSL_Datasets/Lesson 11_Data_Wrangling/11.03_Loading_Indexing_and_Reindexing/HousePrices.csv')

# %%
df['price'].head()
# Out:
# 0     313000.0
# 1    2384000.0
# 2     342000.0
# 3     420000.0
# 4     550000.0
# Name: price, dtype: float64

# %%
df['z_score_price'] = (df['price'] - df['price'].mean())/df['price'].std()

# %%
df.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %%
df['outlier'] = df['z_score_price'].apply(lambda x: 'true' if x>3 else 'false')

# %%
df.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %%
df[df['outlier'] == 'true'].index
# Out:
# Index([   1,  122,  252,  404,  581, 1132, 1543, 1567, 1571, 1600, 1637, 1858,
#        2083, 2286, 2328, 2364, 2654, 2712, 2761, 2772, 2980, 3202, 3284, 3729,
#        3781, 3791, 3863, 3959, 4135, 4261, 4273, 4346, 4350, 4465],
#       dtype='int64')

# %%
df.drop(df[df['outlier'] == 'true'].index, inplace=True)

# %%
df.head()
# Out:
#                   date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00  313000.0       3.0       1.50         1340      7912
# 2  2014-05-02 00:00:00  342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00  420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00  550000.0       4.0       2.50         1940     10500
# 5  2014-05-02 00:00:00  490000.0       2.0       1.00          880      6380
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
# 5     1.0           0     0          3         880              0      1938
#
# ...

# %%
##Describing Data
