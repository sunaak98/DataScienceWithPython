# %%
import sqlite3
import pandas as pd

# %%
df = pd.read_csv('/Users/aakarshan/Documents/Documents HD2/SimpliLearn/New Session/Assignements/Chapter 4/Practice/DataScienceWithPython/OSL_Datasets/Lesson_09_Pandas/9.06_Introduction_to_Pandas_Panel/HousePrices.csv')

# %%
df.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
#    yr_renovated                    street       city  statezip country
# 0          2005      18810 Densmore Ave N  Shoreline  WA 98133     USA
# 1             0           709 W Blaine St    Seattle  WA 98119     USA
# 2             0  26206-26214 143rd Ave SE       Kent  WA 98042     USA
# 3             0           857 170th Pl NE   Bellevue  WA 98008     USA
# 4          1992         9105 170th Ave NE    Redmond  WA 98052     USA

# %%
#create a sqlite3 connection
import sqlite3
connection = sqlite3.connect('database.db')

# %%
df.to_sql('database',connection,if_exists='replace',index=False)
# Out:
# 4600

# %%
#Read data using cursor
cursor = connection.cursor()
query = "select * from database"
cursor.execute(query)

# %%
results = cursor.fetchall()

# %%
results
# Out:
# [('2014-05-02 00:00:00',
#   313000.0,
#   3.0,
#   1.5,
#   1340,
#   7912,
#   1.5,
#   0,
#   0,
#   3,
#   1340,
#   0,
#   1955,
#   2005,
#   '18810 Densmore Ave N',
#   'Shoreline',
#   'WA 98133',
#   'USA'),
#  ('2014-05-02 00:00:00',
#   2384000.0,
#   5.0,
#   2.5,
#   3650,
#   9050,
#   2.0,
#   0,
#   4,
#   5,
#   3370,
#   280,
#   1921,
#   0,
#   '709 W Blaine St',
#   'Seattle',
#   'WA 98119',
#   'USA'),
#  ('2014-05-02 00:00:00',
#   342000.0,
#   3.0,
#   2.0,
#   1930,
#   11947,
#   1.0,
#   0,
#   0,
#   4,
#   1930,
#   0,
#   1966,
#   0,
#   '26206-26214 143rd Ave SE',
#   'Kent',
#   'WA 98042',
#   'USA'),
#  ('2014-05-02 00:00:00',
#   420000.0,
#   3.0,
#   2.25,
#   2000,
#   8030,
#   1.0,
#   0,
#   0,
#   4,
#   1000,
#   1000,
#   1963,
#   0,
#   '857 170th Pl NE',
#   'Bellevue',
#   'WA 98008',
#   'USA'),
#  ('2014-05-02 00:00:00',
#   550000.0,
#   4.0,
#   2.5,
#   1940,
#   10500,
#   1.0,
#   0,
#   0,
#   4,
#   1140,
#   800,
#   1976,
#   1992,
#   '9105 170th Ave NE',
#   'Redmond',
#   'WA 98052',
#   'USA'),
#  ('2014-05-02 00:00:00',
#   490000.0,
#   2.0,
#   1.0,
#   880,
#   6380,
#   1.0,
#   0,
#   0,
#   3,
#   880,
#   0,
#   1938,
#   1994,
#   '522 NE 88th St',
#   'Seattle',
#   'WA 98115',
#   'USA'),
#  ('2014-05-02 00:00:00',
#   335000.0,
#   2.0,
#   2.0,
#   1350,
#   2560,
#   1.0,
#   0,
#   0,
#   3,
#   1350,
#   0,
#   1976,
#   0,
#   '2616 174th Ave NE',
#   'Redmond',
#   'WA 98052',
#   'USA'),
#  ('2014-05-02 00:00:00',
#   482000.0,
#   4.0,
#   2.5,
#   2710,
#   35868,
#   2.0,
#   0,
#   0,
#   3,
#   2710,
#   0,
#   1989,
#   0,
#   '23762 SE 253rd Pl',
#   'Maple Valley',
#   'WA 98038',
#   'USA'),
#  ('2014-05-02 00:00:00',
#   452500.0,
#   3.0,
#   2.5,
#   2430,
#   88426,
#   1.0,
#   0,
#   0,
#   4,
#   1570,
#   860,
#   1985,
#   0,
#   '46611-46625 SE 129th St',
#   'North Bend',
#   'WA 98045',
#   'USA'),
#  ('2014-05-02 00:00:00',
#   640000.0,
#   4.0,
#   2.0,
#   1520,
#   6200,
#   1.5,
#   0,
#   0,
#   3,
#   1520,
#   0,
#   1945,
#   2010,
#   '6811 55th Ave NE',
#   'Seattle',
#   'WA 98115',
#   'USA'),
#  ('2014-05-02 00:00:00',
#   463000.0,
#   3.0,
#   1.75,
#   1710,
#   7320,
#   1.0,
#   0,
#   0,
#   3,
#   1710,
#   0,
#   1948,
#   1994,
#   'Burke-Gilman Trail',
#   'Lake Forest Park',
#   'WA 98155',
#   'USA'),
#  ('2014-05-02 00:00:00',
#   1400000.0,
#   4.0,
#   2.5,
#   2920,
#   4000,
#   1.5,
#   0,
#   0,
#   5,
#   1910,
#   1010,
#   1909,
#   1988,
#   '3838-4098 44th Ave NE',
#   'Seattle',
#   'WA 98105',
#   'USA'),
#  ('2014-05-02 00:00:00',
#   588500.0,
#   3.0,
#   1.75,
#   2330,
#   14892,
#   1.0,
#   0,
#   0,
#   3,
#   1970,
#   360,
#   1980,
#   0,
#   '1833 220th Pl NE',
#   'Sammamish',
#   'WA 98074',
#   'USA'),
#  ('2014-05-02 00:00:00',
#   365000.0,
#   3.0,
#   1.0,
#   1090,
#   6435,
#   1.0,
#   0,
#   0,
#   4,
#   1090,
#   0,
#   1955,
#   2009,
#   '2504 SW Portland Ct',
#   'Seattle',
#   'WA 98106',
#   'USA'),
#  ('2014-05-02 00:00:00',
#   1200000.0,
#   5.0,
#   2.75,
#   2910,
#   9480,
#   1.5,
#   0,
#   0,
#   3,
#   2910,
#   0,
#   1939,
#   1969,
#   '3534 46th Ave NE',
#   'Seattle',
#   'WA 98105',
#   'USA'),
#  ('2014-05-02 00:00:00',
#   242500.0,
#   3.0,
#   1.5,
#   1200,
#   9720,
#   1.0,
#   0,
#   0,
#   4,
#   1200,
#   0,
#   1965,
#   0,
#   '14034 SE 201st St',
#   'Kent',
#   'WA 98042',
#   'USA'),
#  ('2014-05-02 00:00:00',
#   419000.0,
#   3.0,
#   1.5,
#   1570,
#   6700,
#   1.0,
#   0,
#   0,
#   4,
#   1570,
#   0,
#   1956,
#   0,
#   '15424 SE 9th St',
#   'Bellevue',
#   'WA 98007',
#   'USA'),
#  ('2014-05-02 00:00:00',
#   367500.0,
#   4.0,
#   3.0,
#   3110,
#   7231,
#   2.0,
#   0,
#   0,
#   3,
#   3110,
#   0,
#   1997,
#   0,
#   '11224 SE 306th Pl',
#   'Auburn',
#   'WA 98092',
#   'USA'),
#  ('2014-05-02 00:00:00',
#   257950.0,
#   3.0,
#   1.75,
#   1370,
#   5858,
#   1.0,
#   0,
#   0,
#   3,
#   1370,
#   0,
#   1987,
#   2000,
#   '1605 S 245th Pl',
#   'Des Moines',
#   'WA 98198',
#   'USA'),
#  ('2014-05-02 00:00:00',
#   275000.0,
#   3.0,
#   1.5,
#   1180,
#   10277,
#   1.0,
#   0,
#   0,
#   3,
#   1180,
#   0,
#   1983,
#   2009,
#   '12425 415th Ave SE',
#   'North Bend',
#   'WA 98045',
#   'USA'),
#  ('2014-05-02 00:00:00',
#   750000.0,
#   3.0,
#   1.75,
#   2240,
#   10578,
#   2.0,
#   0,
#   0,
#   5,
#   1550,
#   690,
#   1923,
#   0,
#   '3225 NE 92nd St',
#   'Seattle',
#   'WA 98115',
#   'USA'),
#  ('2014-05-02 00:00:00',
#   435000.0,
#   4.0,
#   1.0,
#   1450,
#   8800,
#   1.0,
#   0,
#   0,
#   4,
#   1450,
#   0,
#   1954,
#   1979,
#   '3922 154th Ave SE',
#   'Bellevue',
#   'WA 98006',
#   'USA'),
#  ('2014-05-02 00:00:00',
#   626000.0,
#   3.0,
#   2.25,
#   1750,
#   1572,
#   2.5,
#   0,
#   0,
#   3,
#   1470,
#   280,
#   2005,
#   0,
#   '3140 Franklin Ave E',
#   'Seattle',
#   'WA 98102',
#   'USA'),
#  ('2014-05-02 00:00:00',
#   612500.0,
#   4.0,
#   2.5,
#   2730,
#   12261,
#   2.0,
#   0,
#   0,
#   3,
#   2730,
#   0,
#   1991,
#   0,
#   '10212 NE 156th Pl',
#   'Bothell',
#   'WA 98011',
#   'USA'),
#  ('2014-05-02 00:00:00',
#   495000.0,
#   4.0,
#   1.75,
#   1600,
#   6380,
#   1.0,
#   0,
#   0,
#   3,
#   1130,
#   470,
#   1959,
#   1989,
#   '2021 NE 100th St',
#   'Seattle',
#   'WA 98125',
#   'USA'),
#  ('2014-05-02 00:00:00',
#   285000.0,
#   3.0,
#   2.5,
#   2090,
#   10834,
#   1.0,
#   0,
#   0,
#   4,
#   1360,
#   730,
#   1987,
#   0,
#   '27736 23rd Avenue South',
#   'Federal Way',
#   'WA 98003',
#   'USA'),
#  ('2014-05-02 00:00:00',
#   615000.0,
#   3.0,
#   1.75,
#   2360,
#   7291,
#   1.0,
#   0,
#   0,
#   4,
#   1360,
#   1000,
#   1948,
#   0,
#   '8436-8438 41st Ave SW',
#   'Seattle',
#   'WA 98136',
#   'USA'),
#  ('2014-05-02 00:00:00',
#   698000.0,
#   4.0,
#   2.25,
#   2200,
#   11250,
#   1.5,
#   0,
#   0,
#   5,
#   1300,
#   900,
#   1920,
#   0,
#   '1036 4th St',
#   'Kirkland',
#   'WA 98033',
#   'USA'),
#  ('2014-05-02 00:00:00',
#   675000.0,
#   5.0,
#   2.5,
#   2820,
#   67518,
#   2.0,
#   0,
#   0,
#   3,
#   2820,
#   0,
#   1979,
#   2014,
#   '23525 SE 32nd Way',
#   'Issaquah',
#   'WA 98029',
#   'USA'),
#  ('2014-05-02 00:00:00',
#   790000.0,
#   3.0,
#   2.5,
#   2600,
#   4750,
#   1.0,
#   0,
#   0,
#   4,
#   1700,
#   900,
#   1951,
#   1999,
#   '3314 NW 75th St',
#   'Seattle',
#   'WA 98117',
#   'USA'),
#  ('2014-05-02 00:00:00',
#   382500.0,
#   4.0,
#   1.75,
#   1560,
#   8700,
#   1.0,
#   0,
#   0,
#   4,
#   1560,
#   0,
#   1967,
#   0,
#   '14104 119th Ave NE',
#   'Kirkland',
#   'WA 98034',
#   'USA'),
#  ('2014-05-02 00:00:00',
#   499950.0,
#   4.0,
#   2.5,
#   2860,
#   3345,
#   2.0,
#   0,
#   0,
#   3,
#   2190,
#   670,
#   2004,
#   2003,
#   '20120 137th Ave NE',
#   'Woodinville',
#   'WA 98072',
#   'USA'),
#  ('2014-05-02 00:00:00',
#   650000.0,
#   4.0,
#   2.0,
#   1820,
#   5000,
#   1.5,
#   0,
#   1,
#   3,
#   1640,
#   180,
#   1945,
#   2010,
#   '7201-7399 55th Ave NE',
#   'Seattle',
#   'WA 98115',
#   'USA'),
#  ('2014-05-02 00:00:00',
#   625000.0,
#   4.0,
#   2.5,
#   2820,
#   8408,
#   2.0,
#   0,
#   0,
#   3,
#   2820,
#   0,
#   2014,
#   0,
#   '17052 4th Ave NE',
#   'Shoreline',
#   'WA 98155',
#   'USA'),
#  ('2014-05-02 00:00:00',
#   400000.0,
#   4.0,
#   2.5,
#   3630,
#   42884,
#   1.5,
#   0,
#   0,
#   3,
#   2300,
#   1330,
#   1979,
#   2014,
#   '5172-5198 Heather Ave SE',
#   'Auburn',
#   'WA 98092',
#   'USA'),
#  ('2014-05-02 00:00:00',
#   604000.0,
#   3.0,
#   2.5,
#   3240,
#   33151,
#   2.0,
#   0,
#   2,
#   3,
#   3240,
#   0,
#   1995,
#   0,
#   '30822 36th Ct SW',
#   'Federal Way',
#   'WA 98023',
#   'USA'),
#  ('2014-05-02 00:00:00',
#   440000.0,
#   2.0,
#   1.0,
#   800,
#   4850,
#   1.0,
#   0,
#   0,
#   4,
#   800,
#   0,
#   1944,
#   0,
#   '4801-4899 6th Ave NW',
#   'Seattle',
#   'WA 98107',
#   'USA'),
#  ('2014-05-02 00:00:00',
#   287200.0,
#   3.0,
#   3.0,
#   1850,
#   19966,
#   1.0,
#   0,
#   0,
#   4,
#   1090,
#   760,
#   1992,
#   0,
#   '23017 SE 281st Ct',
#   'Maple Valley',
#   'WA 98038',
#   'USA'),
#  ('2014-05-02 00:00:00',
#   403000.0,
#   3.0,
#   2.0,
#   1960,
#   13100,
#   1.0,
#   0,
#   2,
#   5,
#   1650,
#   310,
#   1957,
#   0,
#   '17825 4th Ave SW',
#   'Normandy Park',
#   'WA 98166',
#   'USA'),
#  ('2014-05-02 00:00:00',
#   750000.0,
#   3.0,
#   2.5,
#   2390,
#   6550,
#   1.0,
#   0,
#   2,
#   4,
#   1440,
#   950,
#   1955,
#   2009,
#   '3628 59th Ave SW',
#   'Seattle',
#   'WA 98116',
#   'USA'),
#  ('2014-05-02 00:00:00',
#   335000.0,
#   3.0,
#   2.25,
#   1580,
#   16215,
#   1.0,
#   0,
#   0,
#   4,
#   1580,
#   0,
#   1978,
#   2000,
#   '4460 332nd Ave SE',
#   'Fall City',
#   'WA 98024',
#   'USA'),
#  ('2014-05-02 00:00:00',
#   260000.0,
#   4.0,
#   2.0,
#   1480,
#   8625,
#   1.0,
#   0,
#   0,
#   4,
#   1480,
#   0,
#   1974,
#   0,
#   '2019 Aberdeen Pl SE',
#   'Renton',
#   'WA 98055',
#   'USA'),
#  ('2014-05-02 00:00:00',
#   308500.0,
#   2.0,
#   1.0,
#   850,
#   6174,
#   1.0,
#   0,
#   0,
#   4,
#   850,
#   0,
#   1950,
#   1983,
#   '121 NE 147th St',
#   'Shoreline',
#   'WA 98155',
#   'USA'),
#  ('2014-05-02 00:00:00',
#   439950.0,
#   3.0,
#   2.5,
#   1770,
#   2875,
#   2.0,
#   0,
#   0,
#   3,
#   1770,
#   0,
#   1990,
#   2009,
#   '4458 51st Ave SW',
#   'Seattle',
#   'WA 98116',
#   'USA'),
#  ('2014-05-02 00:00:00',
#   235000.0,
#   2.0,
#   1.0,
#   1210,
#   9400,
#   1.0,
#   0,
#   0,
#   2,
#   1210,
#   0,
#   1949,
#   0,
#   '7542 21st Ave SW',
#   'Seattle',
#   'WA 98106',
#   'USA'),
#  ('2014-05-02 00:00:00',
#   315000.0,
#   3.0,
#   1.0,
#   1160,
#   9180,
#   1.0,
#   0,
#   0,
#   3,
#   1160,
#   0,
#   1968,
#   1997,
#   '15804 198th Pl NE',
#   'Woodinville',
#   'WA 98077',
#   'USA'),
#  ('2014-05-02 00:00:00',
#   437500.0,
#   3.0,
#   2.25,
#   1970,
#   35100,
#   2.0,
#   0,
#   0,
#   4,
#   1970,
#   0,
#   1977,
#   0,
#   '26069 SE 154th St',
#   'Issaquah',
#   'WA 98027',
#   'USA'),
#  ('2014-05-02 00:00:00',
#   407500.0,
#   3.0,
#   2.5,
#   1930,
#   10460,
#   2.0,
#   0,
#   0,
#   3,
#   1930,
#   0,
#   1996,
#   0,
#   '4314 NE 6th Pl',
#   'Renton',
#   'WA 98059',
#   'USA'),
#  ('2014-05-02 00:00:00',
#   445700.0,
#   3.0,
#   2.5,
#   1270,
#   1180,
#   3.0,
#   0,
#   0,
#   3,
#   1270,
#   0,
#   2001,
#   0,
#   '2640 NW 56th St',
#   'Seattle',
#   'WA 98107',
#   'USA'),
#  ('2014-05-02 00:00:00',
#   838000.0,
#   4.0,
#   2.5,
#   3310,
#   42998,
#   2.0,
#   0,
#   0,
#   3,
#   3310,
#   0,
#   2001,
#   0,
#   '15712 NE 136th Pl',
#   'Redmond',
#   'WA 98052',
#   'USA'),
#  ('2014-05-02 00:00:00',
#   630000.0,
#   4.0,
#   2.75,
#   2710,
#   37277,
#   2.0,
#   0,
#   0,
#   3,
#   2710,
#   0,
#   2000,
#   0,
#   '26429 SE 154th Pl',
#   'Issaquah',
#   'WA 98027',
#   'USA'),
#  ('2014-05-02 00:00:00',
#   550000.0,
#   3.0,
#   1.75,
#   2910,
#   35200,
#   1.5,
#   0,
#   0,
#   3,
#   2910,
#   0,
#   1979,
#   2014,
#   '3923 229th Pl SE',
#   'Sammamish',
#   'WA 98075',
#   'USA'),
#  ('2014-05-02 00:00:00',
#   805000.0,
#   3.0,
#   2.0,
#   2710,
#   4500,
#   1.5,
#   0,
#   0,
#   4,
#   1880,
#   830,
#   1929,
#   0,
#   '6222 30th Ave NE',
#   'Seattle',
#   'WA 98115',
#   'USA'),
#  ('2014-05-02 00:00:00',
#   284000.0,
#   3.0,
#   1.75,
#   1800,
#   23103,
#   1.0,
#   0,
#   0,
#   3,
#   1800,
#   0,
#   1968,
#   1997,
#   '32418 NE 50th St',
#   'Carnation',
#   'WA 98014',
#   'USA'),
#  ('2014-05-02 00:00:00',
#   470000.0,
#   5.0,
#   2.5,
#   2210,
#   9655,
#   1.0,
#   0,
#   0,
#   3,
#   1460,
#   750,
#   1976,
#   0,
#   '19334 89th Ave NE',
#   'Bothell',
#   'WA 98011',
#   'USA'),
#  ('2014-05-02 00:00:00',
#   430000.0,
#   4.0,
#   1.5,
#   1920,
#   10000,
#   1.0,
#   0,
#   0,
#   4,
#   1070,
#   850,
#   1954,
#   1979,
#   '4071 156th Ave SE',
#   'Bellevue',
#   'WA 98006',
#   'USA'),
#  ('2014-05-02 00:00:00',
#   491500.0,
#   4.0,
#   1.75,
#   2190,
#   125452,
#   1.0,
#   0,
#   2,
#   3,
#   2190,
#   0,
#   1968,
#   1997,
#   '36850 204th Ave SE',
#   'Auburn',
#   'WA 98092',
#   'USA'),
#  ('2014-05-02 00:00:00',
#   785000.0,
#   5.0,
#   3.25,
#   3660,
#   11995,
#   2.0,
#   0,
#   2,
#   3,
#   3660,
#   0,
#   2006,
#   0,
#   '7425 Snowberry Ave SE',
#   'Snoqualmie',
#   'WA 98065',
#   'USA'),
#  ('2014-05-02 00:00:00',
#   385000.0,
#   3.0,
#   3.25,
#   1320,
#   1327,
#   2.0,
#   0,
#   0,
#   3,
#   1040,
#   280,
#   2008,
#   0,
#   '3400 21st Ave W',
#   'Seattle',
#   'WA 98199',
#   'USA'),
#  ('2014-05-02 00:00:00',
#   295000.0,
#   2.0,
#   2.5,
#   1630,
#   1368,
#   2.0,
#   0,
#   0,
#   3,
#   1280,
#   350,
#   2009,
#   0,
#   '5944-6082 Delridge Way SW',
#   'Seattle',
#   'WA 98106',
#   'USA'),
#  ('2014-05-02 00:00:00',
#   555000.0,
#   4.0,
#   2.5,
#   3310,
#   6500,
#   2.0,
#   0,
#   0,
#   3,
#   3310,
#   0,
#   2012,
#   1912,
#   '35229 SE Terrace St',
#   'Snoqualmie',
#   'WA 98065',
#   'USA'),
#  ('2014-05-02 00:00:00',
#   459990.0,
#   3.0,
#   2.5,
#   2680,
#   5539,
#   2.0,
#   0,
#   0,
#   3,
#   2680,
#   0,
#   2013,
#   1923,
#   '13800 453rd Ave SE',
#   'North Bend',
#   'WA 98045',
#   'USA'),
#  ('2014-05-02 00:00:00',
#   625000.0,
#   4.0,
#   3.25,
#   2730,
#   54014,
#   1.0,
#   0,
#   0,
#   3,
#   1560,
#   1170,
#   2007,
#   0,
#   '9927 174th Ave SE',
#   'Renton',
#   'WA 98059',
#   'USA'),
#  ('2014-05-02 00:00:00',
#   300000.0,
#   3.0,
#   2.5,
#   2540,
#   5050,
#   2.0,
#   0,
#   0,
#   3,
#   2540,
#   0,
#   2006,
#   0,
#   '29734 215th Terrace SE',
#   'Kent',
#   'WA 98042',
#   'USA'),
#  ('2014-05-03 00:00:00',
#   625000.0,
#   4.0,
#   2.75,
#   2920,
#   6605,
#   2.0,
#   0,
#   0,
#   3,
#   2920,
#   0,
#   2012,
#   1912,
#   '5608 NE 5th Cir',
#   'Renton',
#   'WA 98059',
#   'USA'),
#  ('2014-05-03 00:00:00',
#   553000.0,
#   2.0,
#   1.0,
#   900,
#   5000,
#   1.0,
#   0,
#   0,
#   3,
#   900,
#   0,
#   1944,
#   0,
#   '8053 29th Ave NW',
#   'Seattle',
#   'WA 98117',
#   'USA'),
#  ('2014-05-03 00:00:00',
#   379880.0,
#   3.0,
#   2.5,
#   1650,
#   14054,
#   1.0,
#   0,
#   0,
#   4,
#   1130,
#   520,
#   1986,
#   0,
#   '13256 242nd Pl SE',
#   'Issaquah',
#   'WA 98027',
#   'USA'),
#  ('2014-05-03 00:00:00',
#   310000.0,
#   3.0,
#   1.0,
#   1010,
#   9945,
#   1.0,
#   0,
#   0,
#   4,
#   1010,
#   0,
#   1973,
#   0,
#   '7528 N Fork Rd SE',
#   'Snoqualmie',
#   'WA 98065',
#   'USA'),
#  ('2014-05-04 00:00:00',
#   775000.0,
#   2.0,
#   2.5,
#   2680,
#   7392,
#   1.0,
#   0,
#   0,
#   3,
#   2680,
#   0,
#   2004,
#   2003,
#   '13134 234th Ct NE',
#   'Redmond',
#   'WA 98053',
#   'USA'),
#  ('2014-05-04 00:00:00',
#   365000.0,
#   3.0,
#   2.5,
#   2200,
#   7350,
#   1.0,
#   0,
#   0,
#   5,
#   1570,
#   630,
#   1988,
#   0,
#   '13420 SE 182nd St',
#   'Renton',
#   'WA 98058',
#   'USA'),
#  ('2014-05-04 00:00:00',
#   331950.0,
#   4.0,
#   2.5,
#   2530,
#   9933,
#   2.0,
#   0,
#   2,
#   3,
#   2010,
#   520,
#   1990,
#   2009,
#   '925 48th Ct',
#   'Auburn',
#   'WA 98092',
#   'USA'),
#  ('2014-05-04 00:00:00',
#   783500.0,
#   3.0,
#   2.5,
#   2850,
#   7130,
#   2.0,
#   0,
#   0,
#   3,
#   1990,
#   860,
#   1980,
#   0,
#   '151 Euclid Ave',
#   'Seattle',
#   'WA 98122',
#   'USA'),
#  ('2014-05-04 00:00:00',
#   628000.0,
#   4.0,
#   2.0,
#   2280,
#   6010,
#   1.0,
#   0,
#   0,
#   3,
#   1140,
#   1140,
#   1900,
#   2005,
#   '205-206 Euclid Ave',
#   'Seattle',
#   'WA 98122',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   560000.0,
#   3.0,
#   2.5,
#   1900,
#   8744,
#   2.0,
#   0,
#   0,
#   3,
#   1900,
#   0,
#   1987,
#   2000,
#   '22314 NE 11th Pl',
#   'Sammamish',
#   'WA 98074',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   900000.0,
#   3.0,
#   1.0,
#   1330,
#   77972,
#   1.0,
#   0,
#   0,
#   3,
#   1330,
#   0,
#   1928,
#   1954,
#   '13615 NE 100th St',
#   'Kirkland',
#   'WA 98033',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   531000.0,
#   2.0,
#   3.0,
#   1270,
#   1175,
#   2.0,
#   0,
#   0,
#   3,
#   1110,
#   160,
#   2000,
#   0,
#   '1411 N 48th St',
#   'Seattle',
#   'WA 98103',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   831000.0,
#   4.0,
#   3.0,
#   2170,
#   4000,
#   2.0,
#   0,
#   0,
#   4,
#   1610,
#   560,
#   1982,
#   2011,
#   '120 31st Ave E',
#   'Seattle',
#   'WA 98112',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   780000.0,
#   4.0,
#   2.5,
#   2730,
#   10281,
#   2.0,
#   0,
#   2,
#   3,
#   2730,
#   0,
#   1996,
#   0,
#   '23140 NE 14th Ct',
#   'Sammamish',
#   'WA 98074',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   755000.0,
#   4.0,
#   2.5,
#   2120,
#   10202,
#   1.0,
#   0,
#   0,
#   4,
#   1620,
#   500,
#   1960,
#   2001,
#   '12645 SE 27th St',
#   'Bellevue',
#   'WA 98005',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   705380.0,
#   3.0,
#   2.5,
#   2490,
#   4343,
#   2.0,
#   0,
#   0,
#   3,
#   2490,
#   0,
#   2003,
#   0,
#   '3187 NE Larkspur Ln',
#   'Issaquah',
#   'WA 98029',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   627000.0,
#   4.0,
#   2.25,
#   1990,
#   7712,
#   1.0,
#   0,
#   0,
#   3,
#   1210,
#   780,
#   1973,
#   2013,
#   '18915 SE 42nd Pl',
#   'Issaquah',
#   'WA 98027',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   865000.0,
#   4.0,
#   3.0,
#   3690,
#   9892,
#   2.0,
#   0,
#   0,
#   3,
#   3690,
#   0,
#   1998,
#   2006,
#   '1765 267th Ct SE',
#   'Sammamish',
#   'WA 98075',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   580000.0,
#   2.0,
#   1.0,
#   2540,
#   7000,
#   1.0,
#   0,
#   0,
#   5,
#   1320,
#   1220,
#   1942,
#   0,
#   '8624 Island Dr S',
#   'Seattle',
#   'WA 98118',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   410000.0,
#   3.0,
#   2.25,
#   1800,
#   36704,
#   1.0,
#   0,
#   0,
#   4,
#   1360,
#   440,
#   1978,
#   2000,
#   '24502 SE Mirrormont Dr',
#   'Issaquah',
#   'WA 98027',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   485000.0,
#   4.0,
#   3.0,
#   2340,
#   7048,
#   1.0,
#   0,
#   0,
#   4,
#   1340,
#   1000,
#   1979,
#   0,
#   '14319 85th Pl NE',
#   'Kirkland',
#   'WA 98034',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   400000.0,
#   2.0,
#   1.75,
#   2110,
#   9519,
#   1.0,
#   0,
#   0,
#   2,
#   2110,
#   0,
#   1948,
#   0,
#   '2120 NE 168th St',
#   'Shoreline',
#   'WA 98155',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   549000.0,
#   2.0,
#   1.0,
#   1140,
#   5400,
#   1.0,
#   0,
#   0,
#   5,
#   1140,
#   0,
#   1908,
#   0,
#   '209 30th Ave E',
#   'Seattle',
#   'WA 98112',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   620000.0,
#   3.0,
#   1.75,
#   1480,
#   2185,
#   2.5,
#   0,
#   0,
#   3,
#   1480,
#   0,
#   2005,
#   0,
#   '10512 128th Ave NE',
#   'Kirkland',
#   'WA 98033',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   405000.0,
#   2.0,
#   3.0,
#   1410,
#   1240,
#   2.0,
#   0,
#   0,
#   3,
#   1140,
#   270,
#   2006,
#   0,
#   '9126 45th Ave SW',
#   'Seattle',
#   'WA 98136',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   232000.0,
#   2.0,
#   1.0,
#   1200,
#   8063,
#   1.0,
#   0,
#   0,
#   4,
#   1200,
#   0,
#   1958,
#   1972,
#   '20220 8th Ave S',
#   'Des Moines',
#   'WA 98198',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   800866.0,
#   5.0,
#   2.5,
#   3180,
#   13806,
#   2.0,
#   0,
#   0,
#   4,
#   3180,
#   0,
#   1990,
#   0,
#   '11821 NE 48th Pl',
#   'Kirkland',
#   'WA 98033',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   650000.0,
#   3.0,
#   1.5,
#   2160,
#   9000,
#   1.0,
#   0,
#   2,
#   4,
#   1400,
#   760,
#   1949,
#   1985,
#   '13026 10th Ave NW',
#   'Seattle',
#   'WA 98177',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   823000.0,
#   6.0,
#   1.75,
#   2920,
#   5000,
#   2.5,
#   0,
#   0,
#   4,
#   2780,
#   140,
#   1908,
#   0,
#   '125 29th Ave',
#   'Seattle',
#   'WA 98122',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   770000.0,
#   3.0,
#   2.0,
#   2350,
#   5700,
#   1.5,
#   0,
#   0,
#   4,
#   1810,
#   540,
#   1939,
#   1989,
#   '2171 Boyer Ave E',
#   'Seattle',
#   'WA 98112',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   524000.0,
#   3.0,
#   1.75,
#   1560,
#   5520,
#   1.0,
#   0,
#   0,
#   4,
#   780,
#   780,
#   1944,
#   0,
#   '3434 33rd Ave W',
#   'Seattle',
#   'WA 98199',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   541125.0,
#   5.0,
#   2.75,
#   2740,
#   8426,
#   1.0,
#   0,
#   0,
#   4,
#   1370,
#   1370,
#   1960,
#   2001,
#   '5211 116th Pl SE',
#   'Bellevue',
#   'WA 98006',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   670000.0,
#   3.0,
#   2.5,
#   1680,
#   2000,
#   3.0,
#   0,
#   0,
#   3,
#   1680,
#   0,
#   1909,
#   1998,
#   '3503 NE 44th St',
#   'Seattle',
#   'WA 98105',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   384900.0,
#   5.0,
#   2.5,
#   3090,
#   12750,
#   1.0,
#   0,
#   0,
#   3,
#   1750,
#   1340,
#   1968,
#   1997,
#   '114 SW 292nd St',
#   'Federal Way',
#   'WA 98023',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   406100.0,
#   3.0,
#   2.25,
#   1410,
#   1332,
#   3.0,
#   0,
#   0,
#   3,
#   1410,
#   0,
#   2005,
#   0,
#   '8536 Interlake Ave N',
#   'Seattle',
#   'WA 98103',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   1395000.0,
#   5.0,
#   3.5,
#   4010,
#   8510,
#   2.0,
#   0,
#   1,
#   5,
#   2850,
#   1160,
#   1971,
#   0,
#   '3930 NE Belvoir Pl',
#   'Seattle',
#   'WA 98105',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   736500.0,
#   4.0,
#   2.5,
#   3180,
#   21904,
#   2.0,
#   0,
#   3,
#   3,
#   3180,
#   0,
#   2000,
#   0,
#   '17132 SE 100th St',
#   'Renton',
#   'WA 98059',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   570000.0,
#   3.0,
#   2.25,
#   2010,
#   6000,
#   1.0,
#   0,
#   0,
#   3,
#   1330,
#   680,
#   1975,
#   0,
#   '10204 168th Pl NE',
#   'Redmond',
#   'WA 98052',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   787000.0,
#   3.0,
#   1.75,
#   1330,
#   7500,
#   1.0,
#   0,
#   0,
#   3,
#   1330,
#   0,
#   1961,
#   2004,
#   '218 109th Ave SE',
#   'Bellevue',
#   'WA 98004',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   328000.0,
#   4.0,
#   2.5,
#   2370,
#   6500,
#   2.0,
#   0,
#   0,
#   3,
#   2370,
#   0,
#   1998,
#   2006,
#   '12621 SE 300th Way',
#   'Auburn',
#   'WA 98092',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   435000.0,
#   5.0,
#   2.0,
#   1840,
#   9240,
#   1.0,
#   0,
#   0,
#   4,
#   1540,
#   300,
#   1942,
#   1958,
#   '14013 Ashworth Ave N',
#   'Seattle',
#   'WA 98133',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   499000.0,
#   4.0,
#   2.5,
#   2910,
#   6479,
#   2.0,
#   0,
#   0,
#   3,
#   2910,
#   0,
#   2006,
#   0,
#   '34010 SE Sorenson St',
#   'Snoqualmie',
#   'WA 98065',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   501000.0,
#   4.0,
#   1.0,
#   2070,
#   7519,
#   1.0,
#   0,
#   0,
#   3,
#   1160,
#   910,
#   1963,
#   2008,
#   '2506 166th Ave NE',
#   'Bellevue',
#   'WA 98008',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   1090000.0,
#   4.0,
#   2.5,
#   4340,
#   141570,
#   2.5,
#   0,
#   0,
#   3,
#   4340,
#   0,
#   1992,
#   0,
#   '8814 218th Ave NE',
#   'Redmond',
#   'WA 98053',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   400000.0,
#   2.0,
#   1.0,
#   840,
#   5510,
#   1.0,
#   0,
#   0,
#   3,
#   840,
#   0,
#   1955,
#   2005,
#   '4515 SW Trenton St',
#   'Seattle',
#   'WA 98136',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   220000.0,
#   4.0,
#   1.5,
#   1240,
#   9600,
#   1.0,
#   0,
#   0,
#   3,
#   1240,
#   0,
#   1971,
#   0,
#   '4924 SW 314th Pl',
#   'Federal Way',
#   'WA 98023',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   657100.0,
#   4.0,
#   1.0,
#   1390,
#   4240,
#   1.0,
#   0,
#   0,
#   3,
#   1050,
#   340,
#   1924,
#   2011,
#   '4312 Woodlawn Ave N',
#   'Seattle',
#   'WA 98103',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   309950.0,
#   4.0,
#   2.75,
#   2310,
#   5000,
#   2.0,
#   0,
#   0,
#   3,
#   2310,
#   0,
#   2006,
#   0,
#   '22912 SE 268th Pl',
#   'Maple Valley',
#   'WA 98038',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   300000.0,
#   3.0,
#   2.0,
#   1050,
#   10072,
#   1.0,
#   0,
#   0,
#   3,
#   1050,
#   0,
#   1986,
#   0,
#   '27106 NE Miller St',
#   'Duvall',
#   'WA 98019',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   525888.0,
#   5.0,
#   1.75,
#   2550,
#   71874,
#   1.0,
#   0,
#   0,
#   5,
#   1810,
#   740,
#   1960,
#   0,
#   '13129 195th Pl SE',
#   'Issaquah',
#   'WA 98027',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   740000.0,
#   4.0,
#   1.75,
#   2010,
#   3600,
#   1.5,
#   0,
#   0,
#   3,
#   2010,
#   0,
#   1902,
#   0,
#   '1014 W Garfield St',
#   'Seattle',
#   'WA 98119',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   340000.0,
#   5.0,
#   1.0,
#   1120,
#   9022,
#   1.5,
#   0,
#   0,
#   4,
#   1120,
#   0,
#   1962,
#   0,
#   '14150 75th Ave NE',
#   'Kirkland',
#   'WA 98034',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   398750.0,
#   3.0,
#   2.5,
#   2230,
#   4000,
#   2.0,
#   0,
#   0,
#   3,
#   2230,
#   0,
#   1954,
#   2005,
#   '2601 21st Ave S',
#   'Seattle',
#   'WA 98144',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   206000.0,
#   2.0,
#   1.0,
#   810,
#   7158,
#   1.0,
#   0,
#   0,
#   5,
#   810,
#   0,
#   1944,
#   0,
#   '12807 7th Ave S',
#   'Burien',
#   'WA 98168',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   1030000.0,
#   5.0,
#   2.75,
#   3190,
#   16920,
#   1.0,
#   0,
#   3,
#   3,
#   1690,
#   1500,
#   1976,
#   0,
#   '4529 135th Ave SE',
#   'Bellevue',
#   'WA 98006',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   600000.0,
#   3.0,
#   1.75,
#   1670,
#   39639,
#   1.0,
#   0,
#   0,
#   4,
#   1670,
#   0,
#   1976,
#   1992,
#   '1804 E Beaver Lake Dr SE',
#   'Sammamish',
#   'WA 98075',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   379950.0,
#   4.0,
#   1.75,
#   1970,
#   9389,
#   1.0,
#   0,
#   0,
#   5,
#   1140,
#   830,
#   1960,
#   0,
#   '1701 N 204th Pl',
#   'Shoreline',
#   'WA 98133',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   287000.0,
#   3.0,
#   1.0,
#   1450,
#   6000,
#   1.0,
#   0,
#   0,
#   4,
#   1450,
#   0,
#   1953,
#   1983,
#   '8681 Beacon Ave S',
#   'Seattle',
#   'WA 98118',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   2280000.0,
#   7.0,
#   8.0,
#   13540,
#   307752,
#   3.0,
#   0,
#   4,
#   3,
#   9410,
#   4130,
#   1999,
#   0,
#   '26408 NE 70th St',
#   'Redmond',
#   'WA 98053',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   309950.0,
#   3.0,
#   2.5,
#   1880,
#   7838,
#   2.0,
#   0,
#   0,
#   3,
#   1880,
#   0,
#   1994,
#   0,
#   '17717 113th Pl SE',
#   'Renton',
#   'WA 98055',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   600000.0,
#   3.0,
#   1.75,
#   1880,
#   6360,
#   1.0,
#   0,
#   0,
#   4,
#   1040,
#   840,
#   1945,
#   0,
#   '8040 39th Ave NE',
#   'Seattle',
#   'WA 98115',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   418000.0,
#   3.0,
#   2.0,
#   1410,
#   6030,
#   1.5,
#   0,
#   0,
#   4,
#   1410,
#   0,
#   1930,
#   0,
#   '901 N 97th St',
#   'Seattle',
#   'WA 98103',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   449250.0,
#   4.0,
#   2.0,
#   1480,
#   3844,
#   1.5,
#   0,
#   0,
#   5,
#   1480,
#   0,
#   1928,
#   1970,
#   '519 N 104th St',
#   'Seattle',
#   'WA 98133',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   329950.0,
#   2.0,
#   1.0,
#   1140,
#   5250,
#   1.5,
#   0,
#   0,
#   4,
#   1140,
#   0,
#   1949,
#   1985,
#   '14017 Roslyn Pl N',
#   'Seattle',
#   'WA 98133',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   245000.0,
#   3.0,
#   1.75,
#   1920,
#   9306,
#   1.0,
#   0,
#   0,
#   3,
#   1000,
#   920,
#   1984,
#   0,
#   '30001-30021 55th Pl S',
#   'Auburn',
#   'WA 98001',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   549000.0,
#   4.0,
#   2.5,
#   2910,
#   6338,
#   2.0,
#   0,
#   0,
#   3,
#   2910,
#   0,
#   2008,
#   0,
#   '16026 SE 137th Terrace',
#   'Renton',
#   'WA 98059',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   800000.0,
#   3.0,
#   2.5,
#   3240,
#   7857,
#   2.0,
#   0,
#   0,
#   3,
#   3240,
#   0,
#   1994,
#   0,
#   '22721-22727 SE 27th St',
#   'Sammamish',
#   'WA 98075',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   249950.0,
#   3.0,
#   2.0,
#   1550,
#   15040,
#   1.0,
#   0,
#   0,
#   4,
#   1550,
#   0,
#   1958,
#   1972,
#   '18027 SE 128th St',
#   'Renton',
#   'WA 98059',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   210000.0,
#   5.0,
#   2.0,
#   2050,
#   10200,
#   1.0,
#   0,
#   0,
#   3,
#   1430,
#   620,
#   1956,
#   2001,
#   '20927-20999 2nd Ave S',
#   'Des Moines',
#   'WA 98198',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   1425000.0,
#   2.0,
#   2.5,
#   2220,
#   4000,
#   2.0,
#   0,
#   0,
#   3,
#   2220,
#   0,
#   2000,
#   0,
#   '1857 41st Ave E',
#   'Seattle',
#   'WA 98112',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   585000.0,
#   2.0,
#   1.0,
#   1770,
#   8640,
#   1.5,
#   0,
#   0,
#   3,
#   1520,
#   250,
#   1949,
#   1998,
#   '353 NW 88th St',
#   'Seattle',
#   'WA 98117',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   615000.0,
#   4.0,
#   1.75,
#   2300,
#   11700,
#   1.0,
#   0,
#   0,
#   4,
#   1960,
#   340,
#   1977,
#   0,
#   '18427 NE 26th Way',
#   'Redmond',
#   'WA 98052',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   618500.0,
#   3.0,
#   2.0,
#   1800,
#   5000,
#   1.0,
#   0,
#   0,
#   4,
#   1080,
#   720,
#   1942,
#   1982,
#   '2803 NE 62nd St',
#   'Seattle',
#   'WA 98115',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   487585.0,
#   4.0,
#   1.75,
#   2010,
#   9211,
#   1.0,
#   0,
#   0,
#   3,
#   1470,
#   540,
#   1977,
#   2004,
#   '13313 127th Pl NE',
#   'Kirkland',
#   'WA 98034',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   509900.0,
#   3.0,
#   2.5,
#   1790,
#   2700,
#   2.0,
#   0,
#   0,
#   3,
#   1790,
#   0,
#   2010,
#   0,
#   '4532 185th Ave SE',
#   'Issaquah',
#   'WA 98027',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   631625.0,
#   4.0,
#   2.5,
#   2440,
#   6651,
#   2.0,
#   0,
#   0,
#   3,
#   2440,
#   0,
#   2014,
#   0,
#   '9288-9358 Holman Rd NW',
#   'Seattle',
#   'WA 98117',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   555000.0,
#   3.0,
#   2.5,
#   1940,
#   3211,
#   2.0,
#   0,
#   0,
#   3,
#   1940,
#   0,
#   2009,
#   0,
#   '4509 185th Ave SE',
#   'Issaquah',
#   'WA 98027',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   340000.0,
#   2.0,
#   1.5,
#   1160,
#   1438,
#   2.0,
#   0,
#   0,
#   3,
#   1160,
#   0,
#   2001,
#   0,
#   '1318 29th Ave S',
#   'Seattle',
#   'WA 98144',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   830000.0,
#   4.0,
#   2.5,
#   3400,
#   9692,
#   2.0,
#   0,
#   0,
#   3,
#   3400,
#   0,
#   2007,
#   0,
#   '12001 173rd Pl NE',
#   'Redmond',
#   'WA 98052',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   890000.0,
#   4.0,
#   4.25,
#   4420,
#   5750,
#   2.0,
#   0,
#   0,
#   3,
#   3410,
#   1010,
#   2006,
#   0,
#   '842 Summerhill Ridge Dr NW',
#   'Issaquah',
#   'WA 98027',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   366750.0,
#   3.0,
#   3.0,
#   1571,
#   2017,
#   3.0,
#   0,
#   0,
#   3,
#   1571,
#   0,
#   2008,
#   0,
#   '14359 19th Ave NE',
#   'Seattle',
#   'WA 98125',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   415000.0,
#   3.0,
#   2.25,
#   1620,
#   998,
#   2.5,
#   0,
#   0,
#   3,
#   1540,
#   80,
#   2010,
#   0,
#   '935 4th Ave NE',
#   'Issaquah',
#   'WA 98029',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   416286.0,
#   3.0,
#   2.5,
#   1408,
#   989,
#   3.0,
#   0,
#   0,
#   3,
#   1408,
#   0,
#   2005,
#   0,
#   '7809 12th Ave NE',
#   'Seattle',
#   'WA 98115',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   478000.0,
#   3.0,
#   2.5,
#   3040,
#   4535,
#   2.0,
#   0,
#   0,
#   3,
#   3040,
#   0,
#   2007,
#   0,
#   '2027 Ferndale Ave NE',
#   'Renton',
#   'WA 98056',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   890000.0,
#   5.0,
#   3.5,
#   4490,
#   6000,
#   2.0,
#   0,
#   0,
#   3,
#   3200,
#   1290,
#   2006,
#   0,
#   '792 Summerhill Ridge Dr NW',
#   'Issaquah',
#   'WA 98027',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   419190.0,
#   2.0,
#   2.5,
#   1590,
#   1426,
#   2.0,
#   0,
#   0,
#   3,
#   1590,
#   0,
#   2014,
#   0,
#   '1273 NE Hickory Ln',
#   'Issaquah',
#   'WA 98029',
#   'USA'),
#  ('2014-05-05 00:00:00',
#   712198.0,
#   4.0,
#   2.5,
#   2450,
#   4247,
#   2.0,
#   0,
#   0,
#   3,
#   2450,
#   0,
#   2013,
#   1923,
#   '17122 NE 117th St',
#   'Redmond',
#   'WA 98052',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   397000.0,
#   4.0,
#   2.0,
#   1440,
#   7680,
#   1.0,
#   0,
#   0,
#   3,
#   1200,
#   240,
#   1971,
#   0,
#   '10601 NE 138th Pl',
#   'Kirkland',
#   'WA 98034',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   450000.0,
#   2.0,
#   2.0,
#   1100,
#   3000,
#   1.5,
#   0,
#   0,
#   3,
#   1100,
#   0,
#   1912,
#   2005,
#   '412 NW 70th St',
#   'Seattle',
#   'WA 98117',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   353000.0,
#   3.0,
#   1.0,
#   1350,
#   7740,
#   1.0,
#   0,
#   0,
#   4,
#   860,
#   490,
#   1947,
#   1988,
#   '11051 35th Ave NE',
#   'Seattle',
#   'WA 98125',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   609000.0,
#   4.0,
#   2.5,
#   2150,
#   37981,
#   2.0,
#   0,
#   0,
#   3,
#   2150,
#   0,
#   1985,
#   0,
#   '18114 NE 136th St',
#   'Redmond',
#   'WA 98052',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   234000.0,
#   3.0,
#   1.75,
#   1490,
#   8366,
#   1.0,
#   0,
#   0,
#   4,
#   1010,
#   480,
#   1975,
#   0,
#   '25305 151st Pl SE',
#   'Covington',
#   'WA 98042',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   561000.0,
#   3.0,
#   2.0,
#   2000,
#   7000,
#   2.0,
#   0,
#   0,
#   3,
#   2000,
#   0,
#   1916,
#   1986,
#   '6422 Marshall Ave SW',
#   'Seattle',
#   'WA 98136',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   469000.0,
#   2.0,
#   1.0,
#   1030,
#   4400,
#   1.0,
#   0,
#   0,
#   3,
#   1030,
#   0,
#   1924,
#   2011,
#   '310 NW 72nd St',
#   'Seattle',
#   'WA 98117',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   329350.0,
#   2.0,
#   1.0,
#   720,
#   6687,
#   1.0,
#   0,
#   0,
#   3,
#   720,
#   0,
#   1942,
#   1999,
#   '9712 4th Ave NW',
#   'Seattle',
#   'WA 98117',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   488000.0,
#   5.0,
#   2.0,
#   2020,
#   5000,
#   1.5,
#   0,
#   0,
#   4,
#   2020,
#   0,
#   1938,
#   0,
#   '9020-9024 11th Ave NW',
#   'Seattle',
#   'WA 98117',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   279900.0,
#   3.0,
#   1.75,
#   1580,
#   8151,
#   1.0,
#   0,
#   1,
#   4,
#   1100,
#   480,
#   1962,
#   0,
#   '1629 S 261st Pl',
#   'Des Moines',
#   'WA 98198',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   606000.0,
#   4.0,
#   2.5,
#   2110,
#   13850,
#   2.0,
#   0,
#   0,
#   3,
#   2110,
#   0,
#   1987,
#   2000,
#   '2755 NW Pine Cone Dr',
#   'Issaquah',
#   'WA 98027',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   312000.0,
#   4.0,
#   2.0,
#   1300,
#   7054,
#   1.0,
#   0,
#   0,
#   3,
#   1300,
#   0,
#   1950,
#   2013,
#   '2815 SW 107th St',
#   'Seattle',
#   'WA 98146',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   650000.0,
#   3.0,
#   1.5,
#   1630,
#   7475,
#   1.0,
#   0,
#   1,
#   3,
#   1160,
#   470,
#   1940,
#   1996,
#   '6009 52nd Ave NE',
#   'Seattle',
#   'WA 98115',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   1135000.0,
#   4.0,
#   2.75,
#   3370,
#   8103,
#   1.0,
#   0,
#   3,
#   3,
#   1970,
#   1400,
#   1970,
#   2014,
#   '3922 SW Henderson St',
#   'Seattle',
#   'WA 98136',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   325000.0,
#   4.0,
#   2.5,
#   1890,
#   6156,
#   1.0,
#   0,
#   0,
#   3,
#   980,
#   910,
#   1980,
#   0,
#   '5631 17th Ave SW',
#   'Seattle',
#   'WA 98106',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   425000.0,
#   4.0,
#   2.0,
#   1520,
#   7983,
#   1.0,
#   0,
#   0,
#   5,
#   1520,
#   0,
#   1967,
#   0,
#   '14876 Juanita Woodinville Way NE',
#   'Inglewood-Finn Hill',
#   'WA 98034',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   219000.0,
#   2.0,
#   1.0,
#   900,
#   5160,
#   1.0,
#   0,
#   0,
#   3,
#   900,
#   0,
#   1952,
#   2008,
#   '8652 17th Ave SW',
#   'Seattle',
#   'WA 98106',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   250000.0,
#   3.0,
#   1.0,
#   1050,
#   6874,
#   1.0,
#   0,
#   0,
#   3,
#   1050,
#   0,
#   1954,
#   2005,
#   '18305 Dayton Ave N',
#   'Shoreline',
#   'WA 98133',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   390000.0,
#   3.0,
#   1.75,
#   1260,
#   6500,
#   1.0,
#   0,
#   0,
#   4,
#   1260,
#   0,
#   1966,
#   0,
#   '1415 168th Ave NE',
#   'Bellevue',
#   'WA 98008',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   475000.0,
#   6.0,
#   3.0,
#   3470,
#   117612,
#   1.5,
#   0,
#   0,
#   3,
#   3470,
#   0,
#   1924,
#   2011,
#   '19007 80th Ave NE',
#   'Kenmore',
#   'WA 98028',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   736000.0,
#   4.0,
#   2.5,
#   2290,
#   12047,
#   2.0,
#   0,
#   0,
#   4,
#   2290,
#   0,
#   1988,
#   0,
#   '17435 SE 47th St',
#   'Bellevue',
#   'WA 98006',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   407000.0,
#   4.0,
#   2.25,
#   2810,
#   23400,
#   1.0,
#   0,
#   1,
#   3,
#   1710,
#   1100,
#   1958,
#   2004,
#   '23024-23198 17th Ave S',
#   'Des Moines',
#   'WA 98198',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   272000.0,
#   3.0,
#   2.5,
#   1650,
#   13816,
#   2.0,
#   0,
#   0,
#   3,
#   1650,
#   0,
#   1998,
#   2006,
#   '32000-32072 NE 55th St',
#   'Carnation',
#   'WA 98014',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   362000.0,
#   3.0,
#   2.25,
#   1640,
#   14374,
#   1.0,
#   0,
#   0,
#   4,
#   1140,
#   500,
#   1963,
#   0,
#   '17253 Ambaum Blvd S',
#   'Burien',
#   'WA 98148',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   535000.0,
#   3.0,
#   2.5,
#   1850,
#   10109,
#   2.0,
#   0,
#   0,
#   3,
#   1850,
#   0,
#   1991,
#   0,
#   '8409 NE 129th Pl',
#   'Kirkland',
#   'WA 98034',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   284000.0,
#   4.0,
#   2.5,
#   2000,
#   5390,
#   2.0,
#   0,
#   0,
#   3,
#   2000,
#   0,
#   2003,
#   0,
#   '25434 160th Ave SE',
#   'Kent',
#   'WA 98042',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   367500.0,
#   3.0,
#   1.5,
#   1410,
#   9647,
#   1.0,
#   0,
#   0,
#   3,
#   1410,
#   0,
#   1961,
#   2004,
#   '18048 3rd Ave NW',
#   'Shoreline',
#   'WA 98177',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   379900.0,
#   4.0,
#   1.75,
#   1500,
#   11600,
#   1.0,
#   0,
#   0,
#   4,
#   1000,
#   500,
#   1955,
#   2009,
#   '15007 75th Ave NE',
#   'Kenmore',
#   'WA 98028',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   520000.0,
#   3.0,
#   2.5,
#   2460,
#   54885,
#   2.0,
#   0,
#   0,
#   4,
#   2460,
#   0,
#   1980,
#   0,
#   '5424 NE 10th St',
#   'Renton',
#   'WA 98059',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   175000.0,
#   3.0,
#   1.0,
#   1010,
#   7034,
#   1.0,
#   0,
#   0,
#   3,
#   1010,
#   0,
#   1954,
#   2005,
#   '207 NW 5th St',
#   'Renton',
#   'WA 98057',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   460000.0,
#   2.0,
#   2.25,
#   1230,
#   929,
#   2.0,
#   0,
#   0,
#   3,
#   1020,
#   210,
#   2004,
#   2003,
#   '100 24th Ave E',
#   'Seattle',
#   'WA 98112',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   345000.0,
#   4.0,
#   2.5,
#   2331,
#   3826,
#   2.0,
#   0,
#   0,
#   3,
#   2331,
#   0,
#   2007,
#   0,
#   '11853 SE 176th Ct',
#   'Renton',
#   'WA 98058',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   455000.0,
#   5.0,
#   2.5,
#   2240,
#   7770,
#   1.0,
#   0,
#   0,
#   3,
#   1340,
#   900,
#   1978,
#   0,
#   '12633 NE 133rd Pl',
#   'Kirkland',
#   'WA 98034',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   610000.0,
#   4.0,
#   3.0,
#   2450,
#   10117,
#   1.0,
#   0,
#   0,
#   5,
#   1580,
#   870,
#   1967,
#   0,
#   '15607 SE 42nd Ct',
#   'Bellevue',
#   'WA 98006',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   563000.0,
#   4.0,
#   3.0,
#   3100,
#   15480,
#   2.0,
#   0,
#   0,
#   3,
#   2400,
#   700,
#   1996,
#   0,
#   '7422 NE 163rd St',
#   'Kenmore',
#   'WA 98028',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   612500.0,
#   4.0,
#   2.0,
#   2060,
#   5000,
#   1.0,
#   0,
#   0,
#   3,
#   1030,
#   1030,
#   1949,
#   2013,
#   '1708 NW 96th St',
#   'Seattle',
#   'WA 98117',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   218000.0,
#   3.0,
#   1.75,
#   1850,
#   7684,
#   1.0,
#   0,
#   0,
#   3,
#   1320,
#   530,
#   1979,
#   2014,
#   '33945 28th Pl SW',
#   'Federal Way',
#   'WA 98023',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   404000.0,
#   4.0,
#   1.75,
#   1840,
#   10720,
#   1.0,
#   0,
#   0,
#   3,
#   960,
#   880,
#   1958,
#   2004,
#   '16020 SE 2nd St',
#   'Bellevue',
#   'WA 98008',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   860000.0,
#   4.0,
#   2.0,
#   3740,
#   32417,
#   2.0,
#   0,
#   0,
#   3,
#   3740,
#   0,
#   2000,
#   0,
#   '24507 NE 77th Pl',
#   'Redmond',
#   'WA 98053',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   136500.0,
#   3.0,
#   1.5,
#   1420,
#   8580,
#   1.0,
#   0,
#   0,
#   3,
#   1420,
#   0,
#   1962,
#   2003,
#   '32827 22nd Ave SW',
#   'Federal Way',
#   'WA 98023',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   313950.0,
#   3.0,
#   1.0,
#   1510,
#   6083,
#   1.0,
#   0,
#   0,
#   4,
#   860,
#   650,
#   1940,
#   2001,
#   '415 NE 94th St',
#   'Seattle',
#   'WA 98115',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   575000.0,
#   3.0,
#   1.75,
#   2130,
#   6500,
#   1.0,
#   0,
#   2,
#   3,
#   1170,
#   960,
#   1954,
#   2005,
#   '2214 W Halladay St',
#   'Seattle',
#   'WA 98199',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   1225000.0,
#   4.0,
#   2.25,
#   3490,
#   6906,
#   2.0,
#   0,
#   0,
#   4,
#   2280,
#   1210,
#   1928,
#   0,
#   '2560 39th Ave W',
#   'Seattle',
#   'WA 98199',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   280000.0,
#   3.0,
#   1.75,
#   1630,
#   11800,
#   1.0,
#   0,
#   0,
#   4,
#   1630,
#   0,
#   1971,
#   0,
#   '12525 458th Ave SE',
#   'North Bend',
#   'WA 98045',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   515000.0,
#   3.0,
#   2.5,
#   1790,
#   7167,
#   2.0,
#   0,
#   0,
#   3,
#   1790,
#   0,
#   1989,
#   0,
#   '920 221st Ave NE',
#   'Sammamish',
#   'WA 98074',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   513000.0,
#   4.0,
#   2.5,
#   2000,
#   5684,
#   2.0,
#   0,
#   0,
#   3,
#   2000,
#   0,
#   1996,
#   0,
#   '9041 NE 160th Pl',
#   'Kenmore',
#   'WA 98028',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   599000.0,
#   4.0,
#   2.25,
#   2260,
#   29930,
#   2.0,
#   0,
#   0,
#   4,
#   1400,
#   860,
#   1977,
#   0,
#   '16022 SE 43rd St',
#   'Bellevue',
#   'WA 98006',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   685000.0,
#   4.0,
#   2.5,
#   3030,
#   7864,
#   2.0,
#   0,
#   0,
#   3,
#   3030,
#   0,
#   1999,
#   0,
#   '24201 SE 1st Pl',
#   'Sammamish',
#   'WA 98074',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   365000.0,
#   3.0,
#   1.5,
#   1310,
#   8160,
#   1.0,
#   0,
#   0,
#   3,
#   1310,
#   0,
#   1950,
#   2005,
#   '13714 Ashworth Ave N',
#   'Seattle',
#   'WA 98133',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   762300.0,
#   4.0,
#   2.5,
#   3880,
#   14550,
#   2.0,
#   0,
#   0,
#   3,
#   3880,
#   0,
#   1987,
#   2000,
#   '22344 NE 31st St',
#   'Sammamish',
#   'WA 98074',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   1580000.0,
#   4.0,
#   3.25,
#   3760,
#   10920,
#   1.5,
#   0,
#   0,
#   5,
#   2400,
#   1360,
#   1950,
#   0,
#   '5650 NE 55th St',
#   'Seattle',
#   'WA 98105',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   562000.0,
#   5.0,
#   2.25,
#   3040,
#   8111,
#   2.0,
#   0,
#   0,
#   3,
#   3040,
#   0,
#   1984,
#   0,
#   '17649 NE 129th Pl',
#   'Redmond',
#   'WA 98052',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   530000.0,
#   5.0,
#   2.5,
#   2910,
#   9636,
#   1.0,
#   0,
#   0,
#   4,
#   1690,
#   1220,
#   1964,
#   0,
#   '3250 165th Ave SE',
#   'Bellevue',
#   'WA 98008',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   525000.0,
#   3.0,
#   2.5,
#   2970,
#   11985,
#   1.0,
#   0,
#   0,
#   3,
#   1770,
#   1200,
#   1995,
#   0,
#   '21603 NE 29th St',
#   'Sammamish',
#   'WA 98074',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   484000.0,
#   2.0,
#   1.75,
#   1660,
#   6000,
#   1.0,
#   0,
#   0,
#   3,
#   1160,
#   500,
#   1942,
#   1999,
#   '4711 University View Pl NE',
#   'Seattle',
#   'WA 98105',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   725126.0,
#   4.0,
#   2.5,
#   3200,
#   12369,
#   2.0,
#   0,
#   0,
#   3,
#   3200,
#   0,
#   1998,
#   2006,
#   '14707 SE 84th St',
#   'Newcastle',
#   'WA 98059',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   360000.0,
#   4.0,
#   2.0,
#   2680,
#   18768,
#   1.0,
#   0,
#   0,
#   5,
#   2680,
#   0,
#   1965,
#   0,
#   '31607-31633 44th Ave S',
#   'Auburn',
#   'WA 98001',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   387000.0,
#   3.0,
#   1.0,
#   1230,
#   9568,
#   1.0,
#   0,
#   0,
#   5,
#   1230,
#   0,
#   1962,
#   0,
#   '12116 SE 71st Pl',
#   'Newcastle',
#   'WA 98056',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   483500.0,
#   4.0,
#   2.5,
#   2740,
#   45732,
#   2.0,
#   0,
#   0,
#   3,
#   2740,
#   0,
#   1995,
#   0,
#   '15418 216th Ave NE',
#   'Woodinville',
#   'WA 98077',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   655500.0,
#   4.0,
#   3.5,
#   3380,
#   8330,
#   2.0,
#   0,
#   0,
#   3,
#   3380,
#   0,
#   2000,
#   0,
#   '1703 NW 200th Ln',
#   'Shoreline',
#   'WA 98177',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   345000.0,
#   3.0,
#   1.0,
#   1110,
#   6250,
#   1.0,
#   0,
#   0,
#   3,
#   1110,
#   0,
#   1956,
#   2001,
#   '3230 NE 95th St',
#   'Seattle',
#   'WA 98115',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   533000.0,
#   5.0,
#   2.75,
#   1800,
#   3780,
#   1.5,
#   0,
#   0,
#   3,
#   1400,
#   400,
#   1926,
#   2003,
#   '7434 Winona Ave N',
#   'Seattle',
#   'WA 98103',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   385000.0,
#   3.0,
#   1.75,
#   1900,
#   5520,
#   1.0,
#   0,
#   0,
#   3,
#   1280,
#   620,
#   1982,
#   0,
#   '5215 32nd Ave S',
#   'Seattle',
#   'WA 98118',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   675000.0,
#   2.0,
#   1.0,
#   930,
#   36478,
#   1.0,
#   0,
#   2,
#   3,
#   930,
#   0,
#   1951,
#   1994,
#   '4206 SE Newport Way',
#   'Bellevue',
#   'WA 98006',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   197000.0,
#   3.0,
#   1.75,
#   1690,
#   7735,
#   1.0,
#   0,
#   0,
#   4,
#   1060,
#   630,
#   1976,
#   1992,
#   '30020 43rd Pl S',
#   'Auburn',
#   'WA 98001',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   485000.0,
#   3.0,
#   2.0,
#   1420,
#   4080,
#   1.5,
#   0,
#   0,
#   3,
#   1420,
#   0,
#   1905,
#   2013,
#   '720 N 80th St',
#   'Seattle',
#   'WA 98103',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   1870000.0,
#   5.0,
#   4.0,
#   4510,
#   15175,
#   2.0,
#   0,
#   0,
#   3,
#   4510,
#   0,
#   1969,
#   2002,
#   '8300 SE 82nd St',
#   'Mercer Island',
#   'WA 98040',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   295000.0,
#   3.0,
#   2.25,
#   1980,
#   8000,
#   1.0,
#   0,
#   0,
#   4,
#   1560,
#   420,
#   1974,
#   0,
#   '31966 36th Ave SW',
#   'Federal Way',
#   'WA 98023',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   499000.0,
#   2.0,
#   1.75,
#   1170,
#   2400,
#   1.0,
#   0,
#   0,
#   4,
#   740,
#   430,
#   1903,
#   0,
#   '2112 N 50th St',
#   'Seattle',
#   'WA 98103',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   1050000.0,
#   3.0,
#   2.5,
#   2200,
#   1970,
#   2.0,
#   0,
#   0,
#   3,
#   1610,
#   590,
#   2008,
#   0,
#   '2516 Yale Ave E',
#   'Seattle',
#   'WA 98102',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   191000.0,
#   3.0,
#   1.5,
#   800,
#   8850,
#   1.0,
#   0,
#   0,
#   4,
#   800,
#   0,
#   1959,
#   0,
#   '1003 SW 307th St',
#   'Federal Way',
#   'WA 98023',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   500000.0,
#   3.0,
#   2.5,
#   1480,
#   1171,
#   3.0,
#   0,
#   0,
#   3,
#   1480,
#   0,
#   2006,
#   0,
#   '135 25th Ave E',
#   'Seattle',
#   'WA 98112',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   390000.0,
#   5.0,
#   3.75,
#   2890,
#   5000,
#   1.0,
#   0,
#   0,
#   3,
#   1310,
#   1580,
#   2006,
#   0,
#   '3665 Renton Ave S',
#   'Seattle',
#   'WA 98144',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   979000.0,
#   3.0,
#   2.5,
#   2690,
#   4047,
#   3.0,
#   0,
#   0,
#   3,
#   2690,
#   0,
#   2014,
#   0,
#   '7000 23rd Ave NW',
#   'Seattle',
#   'WA 98117',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   580000.0,
#   4.0,
#   3.25,
#   3569,
#   8327,
#   2.0,
#   0,
#   0,
#   3,
#   3569,
#   0,
#   2013,
#   1923,
#   '710 S 23rd St',
#   'Renton',
#   'WA 98055',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   369950.0,
#   3.0,
#   2.0,
#   1270,
#   1320,
#   3.0,
#   0,
#   0,
#   3,
#   1270,
#   0,
#   2006,
#   0,
#   '8846 Midvale Ave N',
#   'Seattle',
#   'WA 98103',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   1800000.0,
#   5.0,
#   5.0,
#   4490,
#   10279,
#   2.0,
#   0,
#   0,
#   3,
#   3930,
#   560,
#   2013,
#   1923,
#   '1435 104th Ave SE',
#   'Bellevue',
#   'WA 98004',
#   'USA'),
#  ('2014-05-06 00:00:00',
#   776000.0,
#   4.0,
#   2.5,
#   3040,
#   6425,
#   2.0,
#   0,
#   0,
#   3,
#   3040,
#   0,
#   2008,
#   0,
#   '16775 NE 86th Ct',
#   'Redmond',
#   'WA 98052',
#   'USA'),
#  ('2014-05-07 00:00:00',
#   519950.0,
#   3.0,
#   2.25,
#   1170,
#   1249,
#   3.0,
#   0,
#   0,
#   3,
#   1170,
#   0,
#   2014,
#   0,
#   '1749 NW 60th St',
#   'Seattle',
#   'WA 98107',
#   'USA'),
#  ('2014-05-07 00:00:00',
#   255000.0,
#   5.0,
#   2.25,
#   2060,
#   8632,
#   1.0,
#   0,
#   0,
#   3,
#   1030,
#   1030,
#   1962,
#   2003,
#   '105 SW 129th St',
#   'Burien',
#   'WA 98146',
#   'USA'),
#  ('2014-05-07 00:00:00',
#   495000.0,
#   3.0,
#   1.0,
#   990,
#   6000,
#   1.0,
#   0,
#   0,
#   3,
#   990,
#   0,
#   1943,
#   2002,
#   '5628 NE 59th St',
#   'Seattle',
#   'WA 98105',
#   'USA'),
#  ('2014-05-07 00:00:00',
#   510000.0,
#   4.0,
#   2.5,
#   2430,
#   5203,
#   2.0,
#   0,
#   0,
#   3,
#   2430,
#   0,
#   2003,
#   0,
#   '1028 NE 153rd Ct',
#   'Shoreline',
#   'WA 98155',
#   'USA'),
#  ('2014-05-07 00:00:00',
#   1150000.0,
#   4.0,
#   4.0,
#   4460,
#   103382,
#   2.0,
#   0,
#   0,
#   3,
#   4460,
#   0,
#   2001,
#   0,
#   '25823 NE 30th Ct',
#   'Redmond',
#   'WA 98053',
#   'USA'),
#  ('2014-05-07 00:00:00',
#   253000.0,
#   3.0,
#   1.75,
#   1250,
#   10122,
#   1.0,
#   0,
#   0,
#   3,
#   1250,
#   0,
#   1994,
#   0,
#   '25502 Kanasket Dr',
#   'Black Diamond',
#   'WA 98010',
#   'USA'),
#  ('2014-05-07 00:00:00',
#   503000.0,
#   3.0,
#   2.75,
#   1540,
#   6760,
#   1.0,
#   0,
#   0,
#   5,
#   1210,
#   330,
#   1980,
#   0,
#   '9626 NE 129th Pl',
#   'Kirkland',
#   'WA 98034',
#   'USA'),
#  ('2014-05-07 00:00:00',
#   275000.0,
#   3.0,
#   2.5,
#   1600,
#   7000,
#   2.0,
#   0,
#   0,
#   4,
#   1600,
#   0,
#   1993,
#   0,
#   '21326 SE 277th Pl',
#   'Maple Valley',
#   'WA 98038',
#   'USA'),
#  ('2014-05-07 00:00:00',
#   249000.0,
#   3.0,
#   1.0,
#   1110,
#   8423,
#   1.0,
#   0,
#   0,
#   3,
#   1110,
#   0,
#   1952,
#   2008,
#   '14613 6th Ave SW',
#   'Burien',
#   'WA 98166',
#   'USA'),
#  ('2014-05-07 00:00:00',
#   310000.0,
#   3.0,
#   1.75,
#   1840,
#   10723,
#   1.0,
#   0,
#   0,
#   4,
#   1220,
#   620,
#   1974,
#   0,
#   '19313 140th Pl SE',
#   'Renton',
#   'WA 98058',
#   'USA'),
#  ('2014-05-07 00:00:00',
#   750000.0,
#   3.0,
#   2.75,
#   2520,
#   5401,
#   1.0,
#   0,
#   0,
#   4,
#   1360,
#   1160,
#   1946,
#   1989,
#   '2806 13th Ave W',
#   'Seattle',
#   'WA 98119',
#   'USA'),
#  ('2014-05-07 00:00:00',
#   630000.0,
#   3.0,
#   2.5,
#   2680,
#   327135,
#   2.0,
#   0,
#   0,
#   3,
#   2680,
#   0,
#   1995,
#   0,
#   '25339 SE 248th St',
#   'Ravensdale',
#   'WA 98051',
#   'USA'),
#  ('2014-05-07 00:00:00',
#   599999.0,
#   9.0,
#   4.5,
#   3830,
#   6988,
#   2.5,
#   0,
#   0,
#   3,
#   2450,
#   1380,
#   1938,
#   2003,
#   '8809 Densmore Ave N',
#   'Seattle',
#   'WA 98103',
#   'USA'),
#  ('2014-05-07 00:00:00',
#   758000.0,
#   4.0,
#   2.75,
#   2410,
#   9549,
#   1.0,
#   0,
#   0,
#   4,
#   1780,
#   630,
#   1956,
#   0,
#   '10627 NE 45th St',
#   'Kirkland',
#   'WA 98033',
#   'USA'),
#  ('2014-05-07 00:00:00',
#   248500.0,
#   4.0,
#   1.75,
#   1720,
#   10018,
#   1.0,
#   0,
#   0,
#   5,
#   1720,
#   0,
#   1960,
#   0,
#   '16635 SE 268th St',
#   'Covington',
#   'WA 98042',
#   'USA'),
#  ('2014-05-07 00:00:00',
#   310000.0,
#   3.0,
#   1.75,
#   2070,
#   37904,
#   1.0,
#   0,
#   0,
#   4,
#   1420,
#   650,
#   1973,
#   0,
#   '19654 116th Ave SE',
#   'Kent',
#   'WA 98031',
#   'USA'),
#  ('2014-05-07 00:00:00',
#   460000.0,
#   3.0,
#   2.0,
#   1760,
#   9055,
#   2.0,
#   0,
#   0,
#   4,
#   1760,
#   0,
#   1985,
#   0,
#   '5003 159th Ct NE',
#   'Redmond',
#   'WA 98052',
#   'USA'),
#  ('2014-05-07 00:00:00',
#   675000.0,
#   3.0,
#   1.75,
#   1680,
#   10500,
#   1.0,
#   0,
#   0,
#   4,
#   1680,
#   0,
#   1959,
#   0,
#   '4 128th Ave SE',
#   'Bellevue',
#   'WA 98005',
#   'USA'),
#  ('2014-05-07 00:00:00',
#   526000.0,
#   2.0,
#   2.0,
#   1550,
#   2400,
#   1.5,
#   0,
#   0,
#   4,
#   1550,
#   0,
#   1900,
#   1971,
#   '3845 Whitman Ave N',
#   'Seattle',
#   'WA 98103',
#   'USA'),
#  ('2014-05-07 00:00:00',
#   560000.0,
#   3.0,
#   3.0,
#   4120,
#   60392,
#   2.0,
#   0,
#   2,
#   3,
#   3180,
#   940,
#   1994,
#   0,
#   '32223 NE 88th St',
#   'Carnation',
#   'WA 98014',
#   'USA'),
#  ('2014-05-07 00:00:00',
#   415000.0,
#   4.0,
#   3.0,
#   1830,
#   9548,
#   2.0,
#   0,
#   0,
#   3,
#   1830,
#   0,
#   1991,
#   0,
#   '15204 88th Ave NE',
#   'Bothell',
#   'WA 98028',
#   'USA'),
#  ('2014-05-07 00:00:00',
#   246000.0,
#   3.0,
#   1.0,
#   1400,
#   7410,
#   1.0,
#   0,
#   0,
#   3,
#   1400,
#   0,
#   1944,
#   0,
#   '624 SW 137th St',
#   'Burien',
#   'WA 98166',
#   'USA'),
#  ('2014-05-07 00:00:00',
#   314500.0,
#   3.0,
#   1.75,
#   1870,
#   12381,
#   1.0,
#   0,
#   0,
#   4,
#   1870,
#   0,
#   1957,
#   2001,
#   '29645 10th Pl S',
#   'Federal Way',
#   'WA 98003',
#   'USA'),
#  ('2014-05-07 00:00:00',
#   3200000.0,
#   7.0,
#   4.5,
#   6210,
#   8856,
#   2.5,
#   0,
#   2,
#   5,
#   4760,
#   1450,
#   1910,
#   0,
#   '1230 Warren Ave N',
#   'Seattle',
#   'WA 98109',
#   'USA'),
#  ('2014-05-07 00:00:00',
#   420000.0,
#   2.0,
#   1.5,
#   1040,
#   3500,
#   1.5,
#   0,
#   0,
#   4,
#   1040,
#   0,
#   1904,
#   0,
#   '1713 22nd Ave S',
#   'Seattle',
#   'WA 98144',
#   'USA'),
#  ('2014-05-07 00:00:00',
#   535000.0,
#   3.0,
#   1.75,
#   2720,
#   149410,
#   1.5,
#   0,
#   0,
#   3,
#   2720,
#   0,
#   1988,
#   2000,
#   '33331 NE Lake Joy Rd',
#   'Carnation',
#   'WA 98014',
#   'USA'),
#  ('2014-05-07 00:00:00',
#   350000.0,
#   3.0,
#   1.0,
#   1010,
#   9360,
#   1.0,
#   0,
#   0,
#   3,
#   1010,
#   0,
#   1981,
#   2013,
#   '9703 130th Ave NE',
#   'Kirkland',
#   'WA 98033',
#   'USA'),
#  ('2014-05-07 00:00:00',
#   515000.0,
#   3.0,
#   1.75,
#   1580,
#   9147,
#   1.0,
#   0,
#   1,
#   4,
#   1210,
#   370,
#   1967,
#   0,
#   '234 W Lake Sammamish Pkwy SE',
#   'Bellevue',
#   'WA 98008',
#   'USA'),
#  ('2014-05-07 00:00:00',
#   749950.0,
#   4.0,
#   2.75,
#   2600,
#   6050,
#   2.0,
#   0,
#   0,
#   5,
#   1960,
#   640,
#   1949,
#   0,
#   '4140 53rd Ave SW',
#   'Seattle',
#   'WA 98116',
#   'USA'),
#  ('2014-05-07 00:00:00',
#   230000.0,
#   3.0,
#   2.5,
#   1920,
#   9180,
#   2.0,
#   0,
#   0,
#   3,
#   1920,
#   0,
#   1988,
#   2000,
#   '206 Oakesdale Ave SW',
#   'Renton',
#   'WA 98057',
#   'USA'),
#  ('2014-05-07 00:00:00',
#   568000.0,
#   3.0,
#   2.0,
#   2350,
#   5080,
#   1.5,
#   0,
#   0,
#   3,
#   1780,
#   570,
#   1929,
#   0,
#   '5531 Seward Park Ave S',
#   'Seattle',
#   'WA 98118',
#   'USA'),
#  ('2014-05-07 00:00:00',
#   250000.0,
#   1.0,
#   1.0,
#   1100,
#   4373,
#   1.0,
#   0,
#   0,
#   2,
#   820,
#   280,
#   1947,
#   0,
#   '232 SW 154th St',
#   'Burien',
#   'WA 98166',
#   'USA'),
#  ('2014-05-07 00:00:00',
#   581000.0,
#   4.0,
#   2.0,
#   2510,
#   13695,
#   1.0,
#   0,
#   0,
#   4,
#   1280,
#   1230,
#   1961,
#   2001,
#   '11105 126th Ave NE',
#   'Kirkland',
#   'WA 98033',
#   'USA'),
#  ('2014-05-07 00:00:00',
#   651000.0,
#   3.0,
#   2.5,
#   3240,
#   108366,
#   2.0,
#   0,
#   0,
#   4,
#   3240,
#   0,
#   1991,
#   0,
#   '18611 SE 307th Ln',
#   'Kent',
#   'WA 98042',
#   'USA'),
#  ('2014-05-07 00:00:00',
#   600000.0,
#   3.0,
#   2.5,
#   2460,
#   108900,
#   1.0,
#   0,
#   0,
#   4,
#   1860,
#   600,
#   1977,
#   0,
#   '25525 SE 133rd St',
#   'Issaquah',
#   'WA 98027',
#   'USA'),
#  ('2014-05-07 00:00:00',
#   500000.0,
#   2.0,
#   1.0,
#   1010,
#   3885,
#   1.5,
#   0,
#   0,
#   4,
#   1010,
#   0,
#   1906,
#   1990,
#   '331 22nd Ave E',
#   'Seattle',
#   'WA 98112',
#   'USA'),
#  ('2014-05-07 00:00:00',
#   475000.0,
#   2.0,
#   1.0,
#   820,
#   2723,
#   1.0,
#   0,
#   0,
#   3,
#   820,
#   0,
#   1921,
#   2000,
#   '4602 Woodlawn Ave N',
#   'Seattle',
#   'WA 98103',
#   'USA'),
#  ('2014-05-07 00:00:00',
#   352000.0,
#   5.0,
#   2.5,
#   2420,
#   8560,
#   1.0,
#   0,
#   2,
#   3,
#   1620,
#   800,
#   1978,
#   0,
#   '3723 S Chicago St',
#   'Seattle',
#   'WA 98118',
#   'USA'),
#  ('2014-05-07 00:00:00',
#   420000.0,
#   3.0,
#   2.25,
#   1770,
#   8165,
#   2.0,
#   0,
#   0,
#   3,
#   1770,
#   0,
#   1977,
#   2004,
#   '12921 79th Pl NE',
#   'Kirkland',
#   'WA 98034',
#   'USA'),
#  ('2014-05-07 00:00:00',
#   428000.0,
#   2.0,
#   2.0,
#   1350,
#   3900,
#   1.0,
#   0,
#   0,
#   3,
#   1350,
#   0,
#   2003,
#   0,
#   '232nd Way',
# ...
#  ('2014-05-19 00:00:00',
#   350000.0,
#   3.0,
#   2.25,
#   1640,
#   7200,
#   2.0,
#   0,
#   0,
#   4,
#   1640,
#   0,
#   1985,
#   0,
#   '1755 140th Ct SE',
#   'Bellevue',
#   'WA 98007',
#   'USA'),
#  ('2014-05-19 00:00:00',
#   319950.0,
#   4.0,
#   1.75,
#   2310,
#   8045,
#   1.0,
#   0,
#   0,
#   4,
#   1650,
#   660,
#   1976,
#   1992,
#   '16336 131st Ave SE',
#   'Renton',
#   'WA 98058',
#   'USA'),
#  ('2014-05-19 00:00:00',
#   700000.0,
#   3.0,
#   1.75,
#   2010,
#   4905,
#   1.0,
#   0,
#   0,
#   5,
#   1230,
#   780,
#   1912,
#   0,
#   '901 18th Ave',
#   'Seattle',
#   'WA 98122',
#   'USA'),
#  ('2014-05-19 00:00:00',
#   368000.0,
#   2.0,
#   1.5,
#   1660,
#   4680,
#   1.0,
#   0,
#   0,
#   5,
#   830,
#   830,
#   1908,
#   0,
#   '10010 44th Ave SW',
#   'Seattle',
#   'WA 98146',
#   'USA'),
#  ('2014-05-19 00:00:00',
#   433500.0,
#   3.0,
#   2.5,
#   2200,
#   3360,
#   2.0,
#   0,
#   0,
#   3,
#   2200,
#   0,
#   2009,
#   0,
#   '6729 37th Ave S',
#   'Seattle',
#   'WA 98118',
#   'USA'),
#  ('2014-05-19 00:00:00',
#   611000.0,
#   4.0,
#   2.5,
#   2460,
#   4200,
#   2.0,
#   0,
#   0,
#   3,
#   2460,
#   0,
#   1998,
#   2006,
#   '23911 SE 6th St',
#   'Redmond',
#   'WA 98074',
#   'USA'),
#  ('2014-05-19 00:00:00',
#   1000000.0,
#   2.0,
#   1.75,
#   2430,
#   23400,
#   1.0,
#   0,
#   4,
#   3,
#   2430,
#   0,
#   1951,
#   1994,
#   '18200-18298 13th Ave NW',
#   'Shoreline',
#   'WA 98177',
#   'USA'),
#  ('2014-05-19 00:00:00',
#   307000.0,
#   3.0,
#   1.0,
#   1370,
#   7500,
#   1.0,
#   0,
#   0,
#   3,
#   1370,
#   0,
#   1960,
#   2012,
#   '4751 Stephens Ave',
#   'Carnation',
#   'WA 98014',
#   'USA'),
#  ('2014-05-19 00:00:00',
#   442500.0,
#   3.0,
#   1.75,
#   1800,
#   10200,
#   1.0,
#   0,
#   0,
#   3,
#   1800,
#   0,
#   1967,
#   2011,
#   '17110-17116 146th Ave SE',
#   'Renton',
#   'WA 98058',
#   'USA'),
#  ('2014-05-19 00:00:00',
#   485000.0,
#   3.0,
#   1.75,
#   2200,
#   7706,
#   2.0,
#   0,
#   2,
#   3,
#   2200,
#   0,
#   1908,
#   1988,
#   '23902 6th Ave S',
#   'Des Moines',
#   'WA 98198',
#   'USA'),
#  ('2014-05-19 00:00:00',
#   367000.0,
#   2.0,
#   1.0,
#   700,
#   2334,
#   1.0,
#   0,
#   0,
#   3,
#   700,
#   0,
#   1945,
#   2010,
#   '2632 NW North Beach Dr',
#   'Seattle',
#   'WA 98117',
#   'USA'),
#  ('2014-05-19 00:00:00',
#   429000.0,
#   3.0,
#   2.5,
#   1920,
#   15124,
#   2.0,
#   0,
#   0,
#   3,
#   1920,
#   0,
#   1995,
#   0,
#   '714 NE 10th St',
#   'North Bend',
#   'WA 98045',
#   'USA'),
#  ('2014-05-19 00:00:00',
#   446000.0,
#   5.0,
#   2.75,
#   2190,
#   12687,
#   1.0,
#   0,
#   0,
#   5,
#   1370,
#   820,
#   1978,
#   0,
#   '20402 63rd Ave NE',
#   'Kenmore',
#   'WA 98028',
#   'USA'),
#  ('2014-05-19 00:00:00',
#   572500.0,
#   3.0,
#   2.25,
#   2030,
#   9791,
#   1.0,
#   0,
#   0,
#   4,
#   1500,
#   530,
#   1984,
#   0,
#   '13322 SE 77th Ct',
#   'Newcastle',
#   'WA 98059',
#   'USA'),
#  ('2014-05-19 00:00:00',
#   477000.0,
#   3.0,
#   2.5,
#   1350,
#   2053,
#   3.0,
#   0,
#   0,
#   3,
#   1350,
#   0,
#   2005,
#   0,
#   '2313 NW 65th St',
#   'Seattle',
#   'WA 98117',
#   'USA'),
#  ('2014-05-19 00:00:00',
#   518000.0,
#   3.0,
#   2.5,
#   1680,
#   2096,
#   2.0,
#   0,
#   0,
#   3,
#   1380,
#   300,
#   2008,
#   0,
#   '8354 11th Ave NW',
#   'Seattle',
#   'WA 98117',
#   'USA'),
#  ('2014-05-19 00:00:00',
#   462000.0,
#   5.0,
#   1.75,
#   1250,
#   10530,
#   1.0,
#   0,
#   0,
#   4,
#   1250,
#   0,
#   1966,
#   0,
#   '4 151st Pl NE',
#   'Bellevue',
#   'WA 98007',
#   'USA'),
#  ('2014-05-19 00:00:00',
#   1190000.0,
#   4.0,
#   3.0,
#   2240,
#   6000,
#   1.5,
#   0,
#   0,
#   4,
#   1270,
#   970,
#   1914,
#   1945,
#   '2009 4th Ave N',
#   'Seattle',
#   'WA 98109',
#   'USA'),
#  ('2014-05-19 00:00:00',
#   137000.0,
#   3.0,
#   1.0,
#   950,
#   7620,
#   1.0,
#   0,
#   0,
#   3,
#   950,
#   0,
#   1954,
#   2005,
#   '9445 8th Ave SW',
#   'Seattle',
#   'WA 98106',
#   'USA'),
#  ('2014-05-19 00:00:00',
#   530000.0,
#   3.0,
#   3.5,
#   2320,
#   3174,
#   2.0,
#   0,
#   0,
#   3,
#   2060,
#   260,
#   1997,
#   0,
#   '12418 NE 100th St',
#   'Kirkland',
#   'WA 98033',
#   'USA'),
#  ('2014-05-19 00:00:00',
#   818000.0,
#   2.0,
#   2.5,
#   2380,
#   9374,
#   1.0,
#   0,
#   2,
#   3,
#   2380,
#   0,
#   2011,
#   0,
#   '12449 240th Pl NE',
#   'Redmond',
#   'WA 98053',
#   'USA'),
#  ('2014-05-19 00:00:00',
#   640000.0,
#   2.0,
#   2.25,
#   1540,
#   958,
#   3.0,
#   0,
#   0,
#   3,
#   1540,
#   0,
#   2007,
#   0,
#   '1806 11th Ave',
#   'Seattle',
#   'WA 98122',
#   'USA'),
#  ('2014-05-19 00:00:00',
#   298450.0,
#   5.0,
#   3.0,
#   2100,
#   9752,
#   1.0,
#   0,
#   0,
#   3,
#   1200,
#   900,
#   2007,
#   0,
#   '29801-29829 23rd Avenue South',
#   'Federal Way',
#   'WA 98003',
#   'USA'),
#  ('2014-05-19 00:00:00',
#   575000.0,
#   4.0,
#   2.5,
#   2500,
#   4945,
#   2.0,
#   0,
#   0,
#   3,
#   2500,
#   0,
#   2013,
#   1923,
#   '34115 SE Ash St',
#   'Snoqualmie',
#   'WA 98065',
#   'USA'),
#  ('2014-05-20 00:00:00',
#   730000.0,
#   4.0,
#   2.5,
#   3230,
#   7331,
#   2.0,
#   0,
#   0,
#   3,
#   3230,
#   0,
#   2004,
#   2003,
#   '2913 278th Ave SE',
#   'Sammamish',
#   'WA 98075',
#   'USA'),
#  ('2014-05-20 00:00:00',
#   551000.0,
#   3.0,
#   2.5,
#   2830,
#   5802,
#   2.0,
#   0,
#   0,
#   3,
#   2830,
#   0,
#   2001,
#   0,
#   '7928 NE 182nd Pl',
#   'Kenmore',
#   'WA 98028',
#   'USA'),
#  ('2014-05-20 00:00:00',
#   271310.0,
#   2.0,
#   1.0,
#   870,
#   5340,
#   1.5,
#   0,
#   0,
#   2,
#   870,
#   0,
#   1906,
#   0,
#   '2019 24th Ave S',
#   'Seattle',
#   'WA 98144',
#   'USA'),
#  ('2014-05-20 00:00:00',
#   675000.0,
#   4.0,
#   3.0,
#   2690,
#   28300,
#   1.0,
#   0,
#   0,
#   3,
#   2690,
#   0,
#   1954,
#   1999,
#   '17428 7th Pl SW',
#   'Normandy Park',
#   'WA 98166',
#   'USA'),
#  ('2014-05-20 00:00:00',
#   479000.0,
#   3.0,
#   2.5,
#   1260,
#   889,
#   3.0,
#   0,
#   0,
#   3,
#   1260,
#   0,
#   2008,
#   0,
#   '915 6th Ave N',
#   'Seattle',
#   'WA 98109',
#   'USA'),
#  ('2014-05-20 00:00:00',
#   520000.0,
#   4.0,
#   3.5,
#   2680,
#   10000,
#   2.0,
#   0,
#   0,
#   3,
#   2040,
#   640,
#   1942,
#   2014,
#   '13342 30th Ave NE',
#   'Seattle',
#   'WA 98125',
#   'USA'),
#  ('2014-05-20 00:00:00',
#   599950.0,
#   3.0,
#   2.5,
#   2660,
#   4975,
#   2.0,
#   0,
#   0,
#   3,
#   2660,
#   0,
#   2014,
#   0,
#   '4810 S Raymond St',
#   'Seattle',
#   'WA 98118',
#   'USA'),
#  ('2014-05-20 00:00:00',
#   483945.0,
#   2.0,
#   1.75,
#   1480,
#   5120,
#   1.0,
#   0,
#   0,
#   4,
#   840,
#   640,
#   1951,
#   1999,
#   '4844 47th Ave SW',
#   'Seattle',
#   'WA 98116',
#   'USA'),
#  ('2014-05-20 00:00:00',
#   390000.0,
#   4.0,
#   2.25,
#   1770,
#   33132,
#   1.0,
#   0,
#   0,
#   4,
#   1190,
#   580,
#   1965,
#   0,
#   '14223 SE 179th Pl',
#   'Renton',
#   'WA 98058',
#   'USA'),
#  ('2014-05-20 00:00:00',
#   192500.0,
#   2.0,
#   1.0,
#   950,
#   7692,
#   1.0,
#   0,
#   0,
#   3,
#   950,
#   0,
#   1926,
#   2003,
#   '12516 Military Rd S',
#   'Seattle',
#   'WA 98168',
#   'USA'),
#  ('2014-05-20 00:00:00',
#   330000.0,
#   2.0,
#   1.0,
#   860,
#   8308,
#   1.0,
#   0,
#   0,
#   4,
#   860,
#   0,
#   1948,
#   0,
#   '3522 SW 107th St',
#   'Seattle',
#   'WA 98146',
#   'USA'),
#  ('2014-05-20 00:00:00',
#   250000.0,
#   4.0,
#   2.0,
#   1960,
#   7560,
#   1.0,
#   0,
#   0,
#   5,
#   1160,
#   800,
#   1978,
#   0,
#   '12206 SE 217th St',
#   'Kent',
#   'WA 98031',
#   'USA'),
#  ('2014-05-20 00:00:00',
#   243000.0,
#   2.0,
#   1.0,
#   1770,
#   5522,
#   1.5,
#   0,
#   0,
#   4,
#   960,
#   810,
#   1943,
#   0,
#   '8040 S 118th St',
#   'Seattle',
#   'WA 98178',
#   'USA'),
#  ('2014-05-20 00:00:00',
#   575000.0,
#   4.0,
#   1.75,
#   1280,
#   6060,
#   1.0,
#   0,
#   0,
#   3,
#   860,
#   420,
#   1926,
#   2003,
#   '7032 7th Ave NW',
#   'Seattle',
#   'WA 98117',
#   'USA'),
#  ('2014-05-20 00:00:00',
#   639000.0,
#   4.0,
#   2.5,
#   2150,
#   12028,
#   2.0,
#   0,
#   0,
#   4,
#   2150,
#   0,
#   1982,
#   2011,
#   '13615 179th Ave NE',
#   'Redmond',
#   'WA 98052',
#   'USA'),
#  ('2014-05-20 00:00:00',
#   710000.0,
#   2.0,
#   1.0,
#   1790,
#   4000,
#   1.0,
#   0,
#   0,
#   4,
#   1040,
#   750,
#   1923,
#   0,
#   '2422 E McGraw St',
#   'Seattle',
#   'WA 98112',
#   'USA'),
#  ('2014-05-20 00:00:00',
#   675000.0,
#   3.0,
#   2.25,
#   1990,
#   10260,
#   2.0,
#   0,
#   0,
#   4,
#   1990,
#   0,
#   1987,
#   0,
#   '16822 NE 87th St',
#   'Redmond',
#   'WA 98052',
#   'USA'),
#  ('2014-05-20 00:00:00',
#   405000.0,
#   5.0,
#   2.5,
#   2430,
#   4781,
#   2.0,
#   0,
#   0,
#   3,
#   2430,
#   0,
#   2001,
#   0,
#   '16819 SE 171st Pl',
#   'Renton',
#   'WA 98058',
#   'USA'),
#  ('2014-05-20 00:00:00',
#   615000.0,
#   4.0,
#   2.75,
#   2820,
#   13193,
#   1.0,
#   0,
#   0,
#   3,
#   1860,
#   960,
#   1965,
#   1993,
#   '4941-4949 125th Ave SE',
#   'Bellevue',
#   'WA 98006',
#   'USA'),
#  ('2014-05-20 00:00:00',
#   490000.0,
#   3.0,
#   1.0,
#   1910,
#   8190,
#   1.0,
#   0,
#   0,
#   4,
#   1010,
#   900,
#   1946,
#   1989,
#   '9237 7th Ave NW',
#   'Seattle',
#   'WA 98117',
#   'USA'),
#  ('2014-05-20 00:00:00',
#   467000.0,
#   3.0,
#   2.25,
#   1270,
#   1213,
#   2.0,
#   0,
#   0,
#   3,
#   1040,
#   230,
#   2005,
#   0,
#   '1427 NW 62nd St',
#   'Seattle',
#   'WA 98107',
#   'USA'),
#  ('2014-05-20 00:00:00',
#   480000.0,
#   4.0,
#   2.75,
#   2050,
#   3960,
#   1.0,
#   0,
#   0,
#   4,
#   1180,
#   870,
#   1986,
#   0,
#   '2612 49th Ave SW',
#   'Seattle',
#   'WA 98116',
#   'USA'),
#  ('2014-05-20 00:00:00',
#   755000.0,
#   6.0,
#   2.0,
#   2150,
#   4505,
#   1.0,
#   0,
#   0,
#   3,
#   1270,
#   880,
#   1952,
#   2008,
#   '3429 9th Ave W',
#   'Seattle',
#   'WA 98119',
#   'USA'),
#  ('2014-05-20 00:00:00',
#   760000.0,
#   4.0,
#   1.75,
#   2450,
#   13300,
#   1.0,
#   0,
#   2,
#   4,
#   1630,
#   820,
#   1987,
#   0,
#   '5028 157th Ave SE',
#   'Bellevue',
#   'WA 98006',
#   'USA'),
#  ('2014-05-20 00:00:00',
#   387000.0,
#   2.0,
#   2.25,
#   1230,
#   1280,
#   2.0,
#   0,
#   0,
#   3,
#   960,
#   270,
#   2012,
#   1912,
#   '801-921 Martin Luther King Jr Way S',
#   'Seattle',
#   'WA 98144',
#   'USA'),
#  ('2014-05-20 00:00:00',
#   925000.0,
#   4.0,
#   2.25,
#   2260,
#   41984,
#   1.0,
#   0,
#   0,
#   4,
#   2260,
#   0,
#   1967,
#   0,
#   '6046 126th Ave NE',
#   'Kirkland',
#   'WA 98033',
#   'USA'),
#  ('2014-05-20 00:00:00',
#   415000.0,
#   2.0,
#   1.0,
#   1050,
#   60113,
#   1.0,
#   0,
#   0,
#   4,
#   1050,
#   0,
#   1943,
#   0,
#   '3720 S 312th Ln',
#   'Auburn',
#   'WA 98001',
#   'USA'),
#  ('2014-05-20 00:00:00',
#   263000.0,
#   3.0,
#   1.75,
#   1570,
#   7775,
#   2.0,
#   0,
#   0,
#   3,
#   1570,
#   0,
#   1982,
#   0,
#   '9226 S 239th Pl',
#   'Kent',
#   'WA 98031',
#   'USA'),
#  ('2014-05-20 00:00:00',
#   519900.0,
#   4.0,
#   2.0,
#   1820,
#   9350,
#   1.0,
#   0,
#   0,
#   4,
#   1820,
#   0,
#   1967,
#   0,
#   '2019 182nd Ave NE',
#   'Redmond',
#   'WA 98052',
#   'USA'),
#  ('2014-05-20 00:00:00',
#   570000.0,
#   2.0,
#   1.75,
#   1540,
#   4025,
#   1.0,
#   0,
#   0,
#   4,
#   1190,
#   350,
#   1908,
#   0,
#   '1715 46th Ave SW',
#   'Seattle',
#   'WA 98116',
#   'USA'),
#  ('2014-05-20 00:00:00',
#   450000.0,
#   3.0,
#   1.5,
#   2060,
#   44866,
#   1.0,
#   0,
#   0,
#   3,
#   2060,
#   0,
#   1953,
#   0,
#   '21533 NE Woodinville Duvall Rd',
#   'Woodinville',
#   'WA 98077',
#   'USA'),
#  ('2014-05-20 00:00:00',
#   1300000.0,
#   4.0,
#   3.5,
#   4380,
#   74052,
#   1.0,
#   0,
#   0,
#   3,
#   4380,
#   0,
#   2001,
#   0,
#   '5830 246th Pl NE',
#   'Redmond',
#   'WA 98053',
#   'USA'),
#  ('2014-05-20 00:00:00',
#   300000.0,
#   3.0,
#   1.0,
#   1090,
#   9900,
#   1.0,
#   0,
#   0,
#   4,
#   1090,
#   0,
#   1955,
#   2009,
#   '13424 NE 80th St',
#   'Redmond',
#   'WA 98052',
#   'USA'),
#  ('2014-05-20 00:00:00',
#   320000.0,
#   3.0,
#   1.75,
#   1480,
#   7225,
#   1.0,
#   0,
#   0,
#   4,
#   1480,
#   0,
#   1965,
#   0,
#   '2525 NE 24th St',
#   'Renton',
#   'WA 98056',
#   'USA'),
#  ('2014-05-20 00:00:00',
#   387500.0,
#   4.0,
#   1.0,
#   1320,
#   4440,
#   1.5,
#   0,
#   0,
#   3,
#   1320,
#   0,
#   1929,
#   0,
#   '1505 29th Ave',
#   'Seattle',
#   'WA 98122',
#   'USA'),
#  ('2014-05-20 00:00:00',
#   458000.0,
#   1.0,
#   2.25,
#   2140,
#   10350,
#   1.0,
#   0,
#   0,
#   3,
#   1470,
#   670,
#   1976,
#   0,
#   '14634 128th Ave NE',
#   'Woodinville',
#   'WA 98072',
#   'USA'),
#  ('2014-05-20 00:00:00',
#   1212500.0,
#   4.0,
#   3.5,
#   4560,
#   16643,
#   1.0,
#   0,
#   3,
#   3,
#   2230,
#   2330,
#   1995,
#   0,
#   '16864 SE 57th Pl',
#   'Bellevue',
#   'WA 98006',
#   'USA'),
#  ('2014-05-20 00:00:00',
#   380000.0,
#   4.0,
#   3.0,
#   2800,
#   9764,
#   2.0,
#   0,
#   0,
#   3,
#   2800,
#   0,
#   2002,
#   0,
#   '24729 SE 276th Pl',
#   'Maple Valley',
#   'WA 98038',
#   'USA'),
#  ('2014-05-20 00:00:00',
#   200000.0,
#   3.0,
#   1.0,
#   1050,
#   5000,
#   1.0,
#   0,
#   0,
#   4,
#   1050,
#   0,
#   1967,
#   0,
#   '602 Tacoma Ave NE',
#   'Renton',
#   'WA 98056',
#   'USA'),
#  ('2014-05-20 00:00:00',
#   385000.0,
#   3.0,
#   1.5,
#   1490,
#   9630,
#   1.0,
#   0,
#   0,
#   4,
#   1490,
#   0,
#   1959,
#   0,
#   '6428 NE 184th St',
#   'Kenmore',
#   'WA 98028',
#   'USA'),
#  ('2014-05-20 00:00:00',
#   396675.0,
#   2.0,
#   1.0,
#   1730,
#   6375,
#   2.0,
#   0,
#   0,
#   4,
#   1730,
#   0,
#   1945,
#   0,
#   '7358 28th Ave SW',
#   'Seattle',
#   'WA 98126',
#   'USA'),
#  ('2014-05-20 00:00:00',
#   452000.0,
#   4.0,
#   1.0,
#   1210,
#   3760,
#   1.5,
#   0,
#   0,
#   3,
#   1210,
#   0,
#   1900,
#   2005,
#   '1106 N 80th St',
#   'Seattle',
#   'WA 98103',
#   'USA'),
#  ('2014-05-20 00:00:00',
#   426000.0,
#   4.0,
#   2.5,
#   2800,
#   8494,
#   2.0,
#   0,
#   0,
#   3,
#   2800,
#   0,
#   2004,
#   2003,
#   '24957 SE 279th St',
#   'Maple Valley',
#   'WA 98038',
#   'USA'),
#  ('2014-05-20 00:00:00',
#   792000.0,
#   3.0,
#   1.5,
#   1570,
#   1050,
#   2.0,
#   0,
#   0,
#   3,
#   1570,
#   0,
#   1915,
#   0,
#   '1833 1st Ave N',
#   'Seattle',
#   'WA 98109',
#   'USA'),
#  ('2014-05-20 00:00:00',
#   315000.0,
#   3.0,
#   2.25,
#   1400,
#   31626,
#   1.0,
#   0,
#   0,
#   2,
#   1140,
#   260,
#   1987,
#   0,
#   '20515 SE 333rd Pl',
#   'Auburn',
#   'WA 98092',
#   'USA'),
#  ('2014-05-20 00:00:00',
#   1275000.0,
#   4.0,
#   2.0,
#   2850,
#   7861,
#   1.0,
#   0,
#   4,
#   4,
#   1450,
#   1400,
#   1970,
#   0,
#   '3014 NW Esplanade',
#   'Seattle',
#   'WA 98117',
#   'USA'),
#  ('2014-05-20 00:00:00',
#   326000.0,
#   6.0,
#   3.0,
#   1880,
#   7200,
#   1.0,
#   0,
#   0,
#   4,
#   1880,
#   0,
#   1966,
#   0,
#   '1178 Camas Ave NE',
#   'Renton',
#   'WA 98056',
#   'USA'),
#  ('2014-05-20 00:00:00',
#   268500.0,
#   2.0,
#   1.0,
#   790,
#   8424,
#   1.0,
#   0,
#   0,
#   4,
#   790,
#   0,
#   1953,
#   1983,
#   '556 N 167th St',
#   'Shoreline',
#   'WA 98133',
#   'USA'),
#  ('2014-05-20 00:00:00',
#   440000.0,
#   2.0,
#   1.75,
#   1300,
#   4000,
#   2.0,
#   0,
#   0,
#   3,
#   1300,
#   0,
#   1948,
#   1994,
#   '5501 37th Ave NE',
#   'Seattle',
#   'WA 98105',
#   'USA'),
#  ('2014-05-20 00:00:00',
#   300000.0,
#   3.0,
#   1.0,
#   2120,
#   7735,
#   1.0,
#   0,
#   0,
#   4,
#   1060,
#   1060,
#   1967,
#   0,
#   '12840 163rd Ave SE',
#   'Renton',
#   'WA 98059',
#   'USA'),
#  ('2014-05-20 00:00:00',
#   525000.0,
#   3.0,
#   1.5,
#   1540,
#   4773,
#   2.0,
#   0,
#   0,
#   3,
#   1540,
#   0,
#   1941,
#   2009,
#   '4017 36th Ave SW',
#   'Seattle',
#   'WA 98126',
#   'USA'),
#  ('2014-05-20 00:00:00',
#   978000.0,
#   4.0,
#   2.75,
#   2620,
#   13777,
#   1.5,
#   0,
#   2,
#   4,
#   1720,
#   900,
#   1926,
#   1993,
#   '2602 Shoreland Dr S',
#   'Seattle',
#   'WA 98144',
#   'USA'),
#  ('2014-05-20 00:00:00',
#   1125000.0,
#   6.0,
#   3.0,
#   2880,
#   3192,
#   2.0,
#   0,
#   0,
#   4,
#   2180,
#   700,
#   1919,
#   1985,
#   '2212 N 36th St',
#   'Seattle',
#   'WA 98103',
#   'USA'),
#  ('2014-05-20 00:00:00',
#   700000.0,
#   4.0,
#   1.0,
#   1680,
#   4021,
#   1.5,
#   0,
#   0,
#   3,
#   1680,
#   0,
#   1921,
#   2000,
#   '2139 N 52nd St',
#   'Seattle',
#   'WA 98103',
#   'USA'),
#  ('2014-05-20 00:00:00',
#   315000.0,
#   2.0,
#   1.0,
#   790,
#   6969,
#   1.0,
#   0,
#   0,
#   3,
#   790,
#   0,
#   1955,
#   1984,
#   '10830 132nd Ave NE',
#   'Redmond',
#   'WA 98052',
#   'USA'),
#  ('2014-05-20 00:00:00',
#   309000.0,
#   3.0,
#   1.0,
#   1092,
#   7500,
#   1.5,
#   0,
#   0,
#   3,
#   1092,
#   0,
#   1918,
#   0,
#   '7757 15th Ave SW',
#   'Seattle',
#   'WA 98106',
#   'USA'),
#  ('2014-05-20 00:00:00',
#   219950.0,
#   3.0,
#   1.5,
#   1650,
#   9936,
#   1.0,
#   0,
#   0,
#   3,
#   1090,
#   560,
#   1967,
#   2011,
#   '425 S 305th St',
#   'Federal Way',
#   'WA 98003',
#   'USA'),
#  ('2014-05-20 00:00:00',
#   289000.0,
#   3.0,
#   2.5,
#   2090,
#   4700,
#   2.0,
#   0,
#   0,
#   3,
#   2090,
#   0,
#   2002,
#   0,
#   '17814 SE 257th St',
#   'Covington',
#   'WA 98042',
#   'USA'),
#  ('2014-05-20 00:00:00',
#   210000.0,
#   4.0,
#   1.75,
#   2180,
#   28710,
#   1.0,
#   0,
#   0,
#   3,
#   1180,
#   1000,
#   1950,
#   2005,
#   '21922 34th Ave S',
#   'SeaTac',
#   'WA 98198',
#   'USA'),
#  ('2014-05-20 00:00:00',
#   260000.0,
#   4.0,
#   2.5,
#   1990,
#   6671,
#   2.0,
#   0,
#   0,
#   3,
#   1990,
#   0,
#   1989,
#   0,
#   '32819 17th Ave SW',
#   'Federal Way',
#   'WA 98023',
#   'USA'),
#  ('2014-05-20 00:00:00',
#   699000.0,
#   4.0,
#   2.5,
#   2650,
#   7945,
#   2.0,
#   0,
#   0,
#   3,
#   2650,
#   0,
#   2006,
#   0,
#   '11332 30th Ave NE',
#   'Seattle',
#   'WA 98125',
#   'USA'),
#  ('2014-05-20 00:00:00',
#   1800000.0,
#   4.0,
#   3.5,
#   4460,
#   16953,
#   1.0,
#   0,
#   0,
#   3,
#   2550,
#   1910,
#   1962,
#   1994,
#   '2625 82nd Ave NE',
#   'Medina',
#   'WA 98039',
#   'USA'),
#  ('2014-05-20 00:00:00',
#   299950.0,
#   3.0,
#   1.0,
#   910,
#   8000,
#   1.0,
#   0,
#   0,
#   4,
#   740,
#   170,
#   1950,
#   1983,
#   '20013 15th Ave NW',
#   'Shoreline',
#   'WA 98177',
#   'USA'),
#  ('2014-05-20 00:00:00',
#   749950.0,
#   3.0,
#   2.5,
#   2770,
#   10773,
#   2.0,
#   0,
#   2,
#   3,
#   2770,
#   0,
#   1992,
#   0,
#   '16420 SE 39th Pl',
#   'Bellevue',
#   'WA 98008',
#   'USA'),
#  ('2014-05-20 00:00:00',
#   1100000.0,
#   3.0,
#   2.0,
#   2390,
#   6888,
#   2.0,
#   0,
#   1,
#   5,
#   2390,
#   0,
#   1939,
#   0,
#   '7529 Lakemont Dr NE',
#   'Seattle',
#   'WA 98115',
#   'USA'),
#  ('2014-05-20 00:00:00',
#   555000.0,
#   3.0,
#   2.5,
#   3050,
#   158558,
#   1.0,
#   0,
#   0,
#   4,
#   3050,
#   0,
#   1987,
#   0,
#   '701 S 52nd St',
#   'Renton',
#   'WA 98055',
#   'USA'),
#  ...]

# %%
data = pd.read_sql(query,connection)

# %%
data.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
#    yr_renovated                    street       city  statezip country
# 0          2005      18810 Densmore Ave N  Shoreline  WA 98133     USA
# 1             0           709 W Blaine St    Seattle  WA 98119     USA
# 2             0  26206-26214 143rd Ave SE       Kent  WA 98042     USA
# 3             0           857 170th Pl NE   Bellevue  WA 98008     USA
# 4          1992         9105 170th Ave NE    Redmond  WA 98052     USA

# %%
query2 = 'select * from database where city = "Seattle"'

# %%
data = pd.read_sql(query2,connection)

# %%
data.head()
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00  2384000.0       5.0        2.5         3650      9050
# 1  2014-05-02 00:00:00   490000.0       2.0        1.0          880      6380
# 2  2014-05-02 00:00:00   640000.0       4.0        2.0         1520      6200
# 3  2014-05-02 00:00:00  1400000.0       4.0        2.5         2920      4000
# 4  2014-05-02 00:00:00   365000.0       3.0        1.0         1090      6435
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     2.0           0     4          5        3370            280      1921
# 1     1.0           0     0          3         880              0      1938
# 2     1.5           0     0          3        1520              0      1945
# 3     1.5           0     0          5        1910           1010      1909
# 4     1.0           0     0          4        1090              0      1955
#
#    yr_renovated                 street     city  statezip country
# 0             0        709 W Blaine St  Seattle  WA 98119     USA
# 1          1994         522 NE 88th St  Seattle  WA 98115     USA
# 2          2010       6811 55th Ave NE  Seattle  WA 98115     USA
# 3          1988  3838-4098 44th Ave NE  Seattle  WA 98105     USA
# 4          2009    2504 SW Portland Ct  Seattle  WA 98106     USA
